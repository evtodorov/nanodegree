# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from pprint import pprint
from pymongo import MongoClient
client = MongoClient("mongodb://localhost:27017")
db = client.osm_data
sbg = db.SouthBG

# %%
##Display statistics about the database
# mongoschema is available via pip, see also https://github.com/nimeshkverma/mongo_schema/
# some modification were required to make mongoschema compatible with Python 3.6
from mongoschema.mongoschema import Schema
schema = Schema("osm_data", "SouthBG")
num_docs, result = schema.get_schema()
schema.print_schema()
# Out:
# Total number of docs : 1218483
# +-------------------------------+------------------+-----------------------+----------------+-----------------------+
# |              Key              | Occurrence Count | Occurrence Percentage |   Value Type   | Value Type Percentage |
# +-------------------------------+------------------+-----------------------+----------------+-----------------------+
# |              _id              |     1218483      |         100.0         |     other      |         100.0         |
# |             class             |     1218483      |         100.0         | <class 'str'>  |         100.0         |
# |            osm_base           |        1         |          0.0          | <class 'str'>  |         100.0         |
# |              pos              |     1097260      |         90.05         | <class 'list'> |         100.0         |
# |               id              |     1218479      |         100.0         | <class 'str'>  |         100.0         |
# |            created            |     1218479      |         100.0         | <class 'dict'> |         100.0         |
# |           aerodrome           |        4         |          0.0          | <class 'dict'> |         100.0         |
# |            aeroway            |       487        |          0.04         | <class 'str'>  |         100.0         |
# |              icao             |        10        |          0.0          | <class 'str'>  |         100.0         |
# |              name             |      21876       |          1.8          | <class 'dict'> |         100.0         |
# |           local_ref           |        5         |          0.0          | <class 'str'>  |         100.0         |
# |              note             |       1428       |          0.12         | <class 'str'>  |         99.86         |
# |            disused            |        71        |          0.01         | <class 'str'>  |         80.28         |
# |              was              |        3         |          0.0          | <class 'dict'> |         100.0         |
# |            amenity            |       4414       |          0.36         | <class 'str'>  |         100.0         |
# |          admin_level          |       352        |          0.03         | <class 'str'>  |         100.0         |
# |            capital            |        4         |          0.0          | <class 'str'>  |         100.0         |
# |             ekatte            |       533        |          0.04         | <class 'str'>  |         100.0         |
# |             place             |       842        |          0.07         | <class 'str'>  |         100.0         |
# |           population          |        38        |          0.0          | <class 'str'>  |         100.0         |
# |            website            |       413        |          0.03         | <class 'str'>  |         100.0         |
# |            wikidata           |       411        |          0.03         | <class 'str'>  |         100.0         |
# |            old_name           |        26        |          0.0          | <class 'str'>  |         100.0         |
# |            highway            |      43546       |          3.57         | <class 'str'>  |         100.0         |
# |            crossing           |       349        |          0.03         | <class 'str'>  |         98.28         |
# |          crossing_ref         |        7         |          0.0          | <class 'str'>  |         100.0         |
# |             is_in             |       9738       |          0.8          | <class 'str'>  |         94.68         |
# |              ref              |       3125       |          0.26         | <class 'str'>  |         74.82         |
# |             source            |      12200       |          1.0          | <class 'str'>  |         99.56         |
# |           created_by          |       3812       |          0.31         | <class 'str'>  |         100.0         |
# |            railway            |       1593       |          0.13         | <class 'str'>  |         63.03         |
# |            address            |      25917       |          2.13         | <class 'dict'> |         100.0         |
# |          designation          |        12        |          0.0          | <class 'str'>  |         100.0         |
# |            alt_name           |       6993       |          0.57         | <class 'str'>  |          99.9         |
# |          postal_code          |        12        |          0.0          | <class 'str'>  |         100.0         |
# |           importance          |        19        |          0.0          | <class 'str'>  |         100.0         |
# |              ele              |       367        |          0.03         | <class 'str'>  |         100.0         |
# |            natural            |       2938       |          0.24         | <class 'str'>  |         100.0         |
# |            tourism            |       650        |          0.05         | <class 'str'>  |         100.0         |
# |           wheelchair          |       144        |          0.01         | <class 'str'>  |         99.31         |
# |        public_transport       |        64        |          0.01         | <class 'str'>  |         76.56         |
# |            historic           |       358        |          0.03         | <class 'str'>  |         96.37         |
# |             access            |       632        |          0.05         | <class 'str'>  |         100.0         |
# |            bicycle            |       823        |          0.07         | <class 'str'>  |         100.0         |
# |            entrance           |       122        |          0.01         | <class 'str'>  |         100.0         |
# |              foot             |       355        |          0.03         | <class 'str'>  |         100.0         |
# |            man_made           |       7362       |          0.6          | <class 'str'>  |         100.0         |
# |         motor_vehicle         |        73        |          0.01         | <class 'str'>  |         100.0         |
# |            motorcar           |        8         |          0.0          | <class 'str'>  |         100.0         |
# |           motorcycle          |        9         |          0.0          | <class 'str'>  |         88.89         |
# |        traffic_signals        |        40        |          0.0          | <class 'str'>  |          75.0         |
# |             brand             |       102        |          0.01         | <class 'str'>  |         50.98         |
# |            operator           |       326        |          0.03         | <class 'str'>  |         98.47         |
# |              shop             |       1813       |          0.15         | <class 'str'>  |         100.0         |
# |              bus              |        33        |          0.0          | <class 'str'>  |         100.0         |
# |            cuisine            |       190        |          0.02         | <class 'str'>  |         100.0         |
# |          information          |        54        |          0.0          | <class 'str'>  |         100.0         |
# |           board_type          |        18        |          0.0          | <class 'str'>  |         100.0         |
# |              fee              |       173        |          0.01         | <class 'str'>  |         100.0         |
# |            parking            |       219        |          0.02         | <class 'str'>  |         97.72         |
# |           source_ref          |        4         |          0.0          | <class 'str'>  |         100.0         |
# |              url              |        7         |          0.0          | <class 'str'>  |         100.0         |
# |            religion           |       396        |          0.03         | <class 'str'>  |         100.0         |
# |            barrier            |       835        |          0.07         | <class 'str'>  |         100.0         |
# |         opening_hours         |       345        |          0.03         | <class 'str'>  |         99.71         |
# |           generator           |        25        |          0.0          | <class 'dict'> |         100.0         |
# |             power             |      11838       |          0.97         | <class 'str'>  |         100.0         |
# |            waterway           |       2050       |          0.17         | <class 'str'>  |         100.0         |
# |            uic_name           |        3         |          0.0          | <class 'str'>  |         100.0         |
# |            uic_ref            |        5         |          0.0          | <class 'str'>  |         100.0         |
# |              fuel             |        66        |          0.01         | <class 'dict'> |         93.94         |
# |            shelter            |        25        |          0.0          | <class 'str'>  |         100.0         |
# |        button_operated        |        9         |          0.0          | <class 'str'>  |         100.0         |
# |          denomination         |       305        |          0.03         | <class 'str'>  |         100.0         |
# |            building           |      63212       |          5.19         | <class 'str'>  |         66.27         |
# |             noexit            |       106        |          0.01         | <class 'str'>  |         100.0         |
# |            leisure            |       1149       |          0.09         | <class 'str'>  |         100.0         |
# |          traffic_sign         |        23        |          0.0          | <class 'str'>  |         100.0         |
# |           supervised          |        93        |          0.01         | <class 'str'>  |         100.0         |
# |          description          |       288        |          0.02         | <class 'str'>  |         98.26         |
# |          artwork_type         |        8         |          0.0          | <class 'str'>  |         100.0         |
# |             tower             |        47        |          0.0          | <class 'dict'> |         100.0         |
# |              ford             |       363        |          0.03         | <class 'str'>  |         100.0         |
# |             bench             |        23        |          0.0          | <class 'str'>  |         100.0         |
# |         tactile_paving        |        16        |          0.0          | <class 'str'>  |         100.0         |
# |           leaf_type           |       220        |          0.02         | <class 'str'>  |         100.0         |
# |            boundary           |       462        |          0.04         | <class 'str'>  |         100.0         |
# |             marker            |        37        |          0.0          | <class 'str'>  |         100.0         |
# |              atm              |        68        |          0.01         | <class 'str'>  |         100.0         |
# |        health_facility        |        3         |          0.0          | <class 'dict'> |         100.0         |
# |         medical_system        |        3         |          0.0          | <class 'dict'> |         100.0         |
# |        internet_access        |       101        |          0.01         | <class 'str'>  |         72.28         |
# |            smoking            |        63        |          0.01         | <class 'str'>  |         100.0         |
# |             stars             |        27        |          0.0          | <class 'str'>  |         100.0         |
# |             fixme             |       112        |          0.01         | <class 'str'>  |         99.11         |
# |             sport             |       302        |          0.02         | <class 'str'>  |         100.0         |
# |         drinking_water        |        16        |          0.0          | <class 'str'>  |          87.5         |
# |             craft             |        37        |          0.0          | <class 'str'>  |         100.0         |
# |            loc_name           |        3         |          0.0          | <class 'str'>  |         100.0         |
# |             level             |       289        |          0.02         | <class 'str'>  |         100.0         |
# |             phone             |       347        |          0.03         | <class 'str'>  |         100.0         |
# |            clothes            |        13        |          0.0          | <class 'str'>  |         100.0         |
# |            covered            |       126        |          0.01         | <class 'str'>  |         100.0         |
# |             horse             |        82        |          0.01         | <class 'str'>  |         100.0         |
# |           fireplace           |        18        |          0.0          | <class 'str'>  |         100.0         |
# | passenger_information_display |        1         |          0.0          | <class 'str'>  |         100.0         |
# |           emergency           |        14        |          0.0          | <class 'str'>  |         100.0         |
# |            toilets            |        14        |          0.0          | <class 'dict'> |         78.57         |
# |             email             |        66        |          0.01         | <class 'str'>  |         100.0         |
# |            payment            |        49        |          0.0          | <class 'dict'> |         100.0         |
# |             height            |       137        |          0.01         | <class 'str'>  |         100.0         |
# |           route_ref           |        3         |          0.0          | <class 'str'>  |         100.0         |
# |             studio            |        4         |          0.0          | <class 'str'>  |         100.0         |
# |       radar_transponder       |        2         |          0.0          | <class 'str'>  |         100.0         |
# |            capacity           |       125        |          0.01         | <class 'str'>  |          84.8         |
# |           healthcare          |        50        |          0.0          | <class 'str'>  |          94.0         |
# |           park_ride           |        27        |          0.0          | <class 'str'>  |         100.0         |
# |           smoothness          |       2553       |          0.21         | <class 'str'>  |         99.92         |
# |              club             |        3         |          0.0          | <class 'str'>  |         100.0         |
# |        outdoor_seating        |        46        |          0.0          | <class 'str'>  |         100.0         |
# |            takeaway           |        19        |          0.0          | <class 'str'>  |         100.0         |
# |             image             |        4         |          0.0          | <class 'str'>  |         100.0         |
# |          microbrewery         |        3         |          0.0          | <class 'str'>  |         100.0         |
# |            display            |        1         |          0.0          | <class 'str'>  |         100.0         |
# |            support            |        1         |          0.0          | <class 'str'>  |         100.0         |
# |          shelter_type         |        25        |          0.0          | <class 'str'>  |         100.0         |
# |             hiking            |        4         |          0.0          | <class 'str'>  |         100.0         |
# |            map_size           |        1         |          0.0          | <class 'str'>  |         100.0         |
# |            map_type           |        1         |          0.0          | <class 'str'>  |         100.0         |
# |             office            |       200        |          0.02         | <class 'str'>  |         100.0         |
# |            contact            |        8         |          0.0          | <class 'dict'> |         100.0         |
# |             FIXME             |        34        |          0.0          | <class 'str'>  |         100.0         |
# |            distance           |        11        |          0.0          | <class 'str'>  |         100.0         |
# |             name_1            |        3         |          0.0          | <class 'str'>  |         100.0         |
# |            surface            |       4219       |          0.35         | <class 'str'>  |         100.0         |
# |           dispensing          |        8         |          0.0          | <class 'str'>  |         100.0         |
# |           government          |        11        |          0.0          | <class 'str'>  |         100.0         |
# |        traffic_calming        |        55        |          0.0          | <class 'str'>  |         100.0         |
# |             train             |        9         |          0.0          | <class 'str'>  |         100.0         |
# |             indoor            |       235        |          0.02         | <class 'str'>  |         100.0         |
# |             layer             |       1919       |          0.16         | <class 'str'>  |         100.0         |
# |            backrest           |        25        |          0.0          | <class 'str'>  |         100.0         |
# |            material           |        29        |          0.0          | <class 'str'>  |         100.0         |
# |             seats             |        3         |          0.0          | <class 'str'>  |         100.0         |
# |              beds             |        1         |          0.0          | <class 'str'>  |         100.0         |
# |             rooms             |        5         |          0.0          | <class 'str'>  |         100.0         |
# |           milestone           |        2         |          0.0          | <class 'str'>  |         100.0         |
# |             unisex            |        4         |          0.0          | <class 'str'>  |         100.0         |
# |            service            |       1333       |          0.11         | <class 'str'>  |         99.55         |
# |           frequency           |       383        |          0.03         | <class 'str'>  |         100.0         |
# |           site_type           |       121        |          0.01         | <class 'str'>  |         100.0         |
# |            memorial           |        21        |          0.0          | <class 'str'>  |         100.0         |
# |            currency           |        10        |          0.0          | <class 'dict'> |         100.0         |
# |            vending            |        65        |          0.01         | <class 'str'>  |         100.0         |
# |             repair            |        5         |          0.0          | <class 'str'>  |         100.0         |
# |            location           |        2         |          0.0          | <class 'str'>  |         100.0         |
# |              lit              |       166        |          0.01         | <class 'str'>  |         100.0         |
# |              kerb             |        22        |          0.0          | <class 'str'>  |         100.0         |
# |            maxspeed           |       2248       |          0.18         | <class 'str'>  |         99.15         |
# |         drive_through         |        11        |          0.0          | <class 'str'>  |         100.0         |
# |            delivery           |        6         |          0.0          | <class 'str'>  |         100.0         |
# |             screen            |        1         |          0.0          | <class 'str'>  |         100.0         |
# |           maxheight           |        4         |          0.0          | <class 'str'>  |         100.0         |
# |            airmark            |        1         |          0.0          | <class 'str'>  |         100.0         |
# |             beacon            |        1         |          0.0          | <class 'dict'> |         100.0         |
# |           whitewater          |        8         |          0.0          | <class 'dict'> |          75.0         |
# |          bunker_type          |        3         |          0.0          | <class 'str'>  |         100.0         |
# |            military           |        14        |          0.0          | <class 'str'>  |         100.0         |
# |             hoops             |        5         |          0.0          | <class 'str'>  |         100.0         |
# |         service_times         |        1         |          0.0          | <class 'str'>  |         100.0         |
# |         megalith_type         |        2         |          0.0          | <class 'str'>  |         100.0         |
# |            seamark            |        6         |          0.0          | <class 'dict'> |         100.0         |
# |            organic            |        3         |          0.0          | <class 'str'>  |         100.0         |
# |             sells             |        2         |          0.0          | <class 'dict'> |         100.0         |
# |             beauty            |        1         |          0.0          | <class 'str'>  |         100.0         |
# |             female            |        2         |          0.0          | <class 'str'>  |         100.0         |
# |           direction           |        7         |          0.0          | <class 'str'>  |         100.0         |
# |        social_facility        |        8         |          0.0          | <class 'dict'> |          87.5         |
# |            country            |        4         |          0.0          | <class 'str'>  |         100.0         |
# |           diplomatic          |        3         |          0.0          | <class 'str'>  |         100.0         |
# |              fax              |        2         |          0.0          | <class 'str'>  |         100.0         |
# |          artist_name          |        1         |          0.0          | <class 'str'>  |         100.0         |
# |           historic_2          |        1         |          0.0          | <class 'str'>  |         100.0         |
# |            cash_in            |        1         |          0.0          | <class 'str'>  |         100.0         |
# |          inscription          |        4         |          0.0          | <class 'str'>  |         100.0         |
# |             table             |        2         |          0.0          | <class 'str'>  |         100.0         |
# |          guest_house          |        3         |          0.0          | <class 'str'>  |         100.0         |
# |              bar              |        3         |          0.0          | <class 'str'>  |         100.0         |
# |            brewery            |        2         |          0.0          | <class 'str'>  |         100.0         |
# |            landuse            |       3932       |          0.32         | <class 'str'>  |         100.0         |
# |              pump             |        1         |          0.0          | <class 'str'>  |         100.0         |
# |              door             |        2         |          0.0          | <class 'str'>  |         100.0         |
# |              flag             |        3         |          0.0          | <class 'str'>  |         66.67         |
# |            agrarian           |        3         |          0.0          | <class 'str'>  |         100.0         |
# |           start_date          |        6         |          0.0          | <class 'str'>  |         100.0         |
# |           playground          |        3         |          0.0          | <class 'str'>  |         66.67         |
# |         communication         |        3         |          0.0          | <class 'dict'> |         100.0         |
# |        air_conditioning       |        3         |          0.0          | <class 'str'>  |         100.0         |
# |           short_name          |        8         |          0.0          | <class 'str'>  |          50.0         |
# |        departures_board       |        1         |          0.0          | <class 'str'>  |         100.0         |
# |            wetland            |        78        |          0.01         | <class 'str'>  |         100.0         |
# |             bridge            |       1313       |          0.11         | <class 'str'>  |         99.54         |
# |           denotation          |        2         |          0.0          | <class 'str'>  |         100.0         |
# |            diameter           |        2         |          0.0          | <class 'str'>  |         100.0         |
# |            aircraft           |        1         |          0.0          | <class 'dict'> |         100.0         |
# |          second_hand          |        28        |          0.0          | <class 'str'>  |         100.0         |
# |             design            |        4         |          0.0          | <class 'str'>  |         100.0         |
# |        line_attachment        |        4         |          0.0          | <class 'str'>  |         100.0         |
# |           impromptu           |        2         |          0.0          | <class 'str'>  |         100.0         |
# |             bottle            |        1         |          0.0          | <class 'str'>  |         100.0         |
# |            fountain           |        1         |          0.0          | <class 'str'>  |         100.0         |
# |          intermittent         |       322        |          0.03         | <class 'str'>  |         100.0         |
# |            refitted           |        1         |          0.0          | <class 'str'>  |         100.0         |
# |              hgv              |        2         |          0.0          | <class 'str'>  |         100.0         |
# |           leaf_cycle          |        2         |          0.0          | <class 'str'>  |         100.0         |
# |         recycling_type        |        1         |          0.0          | <class 'str'>  |         100.0         |
# |           node_refs           |      120256      |          9.87         | <class 'list'> |         100.0         |
# |           sac_scale           |        85        |          0.01         | <class 'str'>  |         100.0         |
# |           tracktype           |       1300       |          0.11         | <class 'str'>  |         100.0         |
# |            heading            |        3         |          0.0          | <class 'str'>  |         100.0         |
# |            incline            |        26        |          0.0          | <class 'str'>  |         100.0         |
# |             length            |        5         |          0.0          | <class 'str'>  |         100.0         |
# |             width             |       180        |          0.01         | <class 'str'>  |         100.0         |
# |             oneway            |       3218       |          0.26         | <class 'str'>  |         100.0         |
# |            history            |        9         |          0.0          | <class 'str'>  |         100.0         |
# |            int_ref            |       261        |          0.02         | <class 'str'>  |         100.0         |
# |             lanes             |       1929       |          0.16         | <class 'str'>  |         100.0         |
# |          destination          |        86        |          0.01         | <class 'dict'> |         69.77         |
# |             water             |       280        |          0.02         | <class 'str'>  |         100.0         |
# |              ship             |        2         |          0.0          | <class 'str'>  |         100.0         |
# |            visible            |        59        |          0.0          | <class 'str'>  |         100.0         |
# |            junction           |       105        |          0.01         | <class 'str'>  |         100.0         |
# |            nat_ref            |       159        |          0.01         | <class 'str'>  |         100.0         |
# |          electrified          |       600        |          0.05         | <class 'str'>  |         100.0         |
# |             gauge             |       602        |          0.05         | <class 'str'>  |         100.0         |
# |             usage             |       515        |          0.04         | <class 'str'>  |         100.0         |
# |            voltage            |       452        |          0.04         | <class 'str'>  |         100.0         |
# |        passenger_lines        |       123        |          0.01         | <class 'str'>  |         100.0         |
# |            sidewalk           |        32        |          0.0          | <class 'str'>  |          87.5         |
# |             tunnel            |       568        |          0.05         | <class 'str'>  |         100.0         |
# |             ruins             |        12        |          0.0          | <class 'str'>  |         100.0         |
# |              roof             |        10        |          0.0          | <class 'dict'> |          80.0         |
# |              mtb              |       384        |          0.03         | <class 'dict'> |         100.0         |
# |            footway            |       140        |          0.01         | <class 'str'>  |         100.0         |
# |             tracks            |        25        |          0.0          | <class 'str'>  |         100.0         |
# |          maxaxleload          |        21        |          0.0          | <class 'str'>  |         100.0         |
# |           segregated          |        18        |          0.0          | <class 'str'>  |         100.0         |
# |             narrow            |        7         |          0.0          | <class 'str'>  |         100.0         |
# |              turn             |        19        |          0.0          | <class 'dict'> |         100.0         |
# |        trail_visibility       |        68        |          0.01         | <class 'str'>  |         100.0         |
# |           fence_type          |        34        |          0.0          | <class 'str'>  |         100.0         |
# |              boat             |        19        |          0.0          | <class 'str'>  |         100.0         |
# |           est_width           |        9         |          0.0          | <class 'str'>  |         100.0         |
# |            theatre            |        2         |          0.0          | <class 'dict'> |         100.0         |
# |              ski              |        16        |          0.0          | <class 'str'>  |         100.0         |
# |           snowmobile          |        14        |          0.0          | <class 'str'>  |         100.0         |
# |            cutting            |        5         |          0.0          | <class 'str'>  |         100.0         |
# |            maxstay            |        4         |          0.0          | <class 'str'>  |         100.0         |
# |             wires             |        40        |          0.0          | <class 'str'>  |         100.0         |
# |           embankment          |        29        |          0.0          | <class 'str'>  |         100.0         |
# |              area             |       110        |          0.01         | <class 'str'>  |         98.18         |
# |          construction         |        30        |          0.0          | <class 'str'>  |         93.33         |
# |             garden            |        2         |          0.0          | <class 'dict'> |         100.0         |
# |             cables            |        38        |          0.0          | <class 'str'>  |         100.0         |
# |            handrail           |        8         |          0.0          | <class 'str'>  |         100.0         |
# |              ramp             |        3         |          0.0          | <class 'str'>  |         100.0         |
# |           motorroad           |        8         |          0.0          | <class 'str'>  |         100.0         |
# |              osmc             |        31        |          0.0          | <class 'dict'> |         100.0         |
# |            vehicle            |        16        |          0.0          | <class 'str'>  |         100.0         |
# |           esperanto           |        2         |          0.0          | <class 'str'>  |         100.0         |
# |           substance           |        27        |          0.0          | <class 'str'>  |         100.0         |
# |            resource           |        2         |          0.0          | <class 'str'>  |         100.0         |
# |             floors            |        10        |          0.0          | <class 'str'>  |         100.0         |
# |             panel             |        10        |          0.0          | <class 'str'>  |         100.0         |
# |            typology           |        10        |          0.0          | <class 'str'>  |         100.0         |
# |              CLC              |       312        |          0.03         | <class 'dict'> |         100.0         |
# |          residential          |        11        |          0.0          | <class 'str'>  |         100.0         |
# |           abandoned           |        12        |          0.0          | <class 'str'>  |          50.0         |
# |            cycleway           |        22        |          0.0          | <class 'str'>  |         77.27         |
# |            proposed           |        1         |          0.0          | <class 'str'>  |         100.0         |
# |           aerialway           |        1         |          0.0          | <class 'str'>  |         100.0         |
# |          border_type          |        4         |          0.0          | <class 'str'>  |         100.0         |
# |             dance             |        1         |          0.0          | <class 'dict'> |         100.0         |
# |             plant             |        3         |          0.0          | <class 'dict'> |         100.0         |
# |              wdb              |        3         |          0.0          | <class 'dict'> |         100.0         |
# |           substation          |        3         |          0.0          | <class 'str'>  |         100.0         |
# |             colour            |        11        |          0.0          | <class 'str'>  |         100.0         |
# |            disabled           |        1         |          0.0          | <class 'str'>  |         100.0         |
# |           PDF_layer           |       816        |          0.07         | <class 'str'>  |         100.0         |
# |         PDF_lineColor         |       816        |          0.07         | <class 'str'>  |         100.0         |
# |             PDF_nr            |       685        |          0.06         | <class 'str'>  |         100.0         |
# |           PDF_closed          |       806        |          0.07         | <class 'str'>  |         100.0         |
# |              road             |        2         |          0.0          | <class 'str'>  |         100.0         |
# |           maxweight           |        1         |          0.0          | <class 'str'>  |         100.0         |
# |           website_1           |        1         |          0.0          | <class 'str'>  |         100.0         |
# |            fishing            |        1         |          0.0          | <class 'str'>  |         100.0         |
# |            4wd_only           |        2         |          0.0          | <class 'str'>  |         100.0         |
# |          bicycle_road         |        17        |          0.0          | <class 'str'>  |         100.0         |
# |             speed             |        20        |          0.0          | <class 'str'>  |         100.0         |
# |          backcountry          |        1         |          0.0          | <class 'str'>  |         100.0         |
# |            caravans           |        1         |          0.0          | <class 'str'>  |         100.0         |
# |            openfire           |        1         |          0.0          | <class 'str'>  |         100.0         |
# |          power_supply         |        2         |          0.0          | <class 'str'>  |         100.0         |
# |     sanitary_dump_station     |        3         |          0.0          | <class 'str'>  |         100.0         |
# |             tents             |        1         |          0.0          | <class 'str'>  |         100.0         |
# |           elevation           |        2         |          0.0          | <class 'str'>  |         100.0         |
# |              crop             |        42        |          0.0          | <class 'str'>  |         100.0         |
# |           building_1          |        1         |          0.0          | <class 'str'>  |         100.0         |
# |           operator_1          |        1         |          0.0          | <class 'str'>  |         100.0         |
# |           historic_1          |        1         |          0.0          | <class 'str'>  |         100.0         |
# |             symbol            |        3         |          0.0          | <class 'str'>  |         100.0         |
# |          cable_number         |        1         |          0.0          | <class 'str'>  |         100.0         |
# |           industrial          |        17        |          0.0          | <class 'str'>  |         100.0         |
# |          agricultural         |        1         |          0.0          | <class 'str'>  |         100.0         |
# |         reservoir_type        |        10        |          0.0          | <class 'str'>  |         100.0         |
# |            network            |       163        |          0.01         | <class 'str'>  |         100.0         |
# |             shower            |        3         |          0.0          | <class 'str'>  |         100.0         |
# |          surveillance         |        3         |          0.0          | <class 'str'>  |         66.67         |
# |             noname            |        1         |          0.0          | <class 'str'>  |         100.0         |
# |           crossing_1          |        2         |          0.0          | <class 'str'>  |         100.0         |
# |           highway_1           |        1         |          0.0          | <class 'str'>  |         100.0         |
# |            floating           |        1         |          0.0          | <class 'str'>  |         100.0         |
# |              type             |       966        |          0.08         | <class 'str'>  |         100.0         |
# |           community           |        2         |          0.0          | <class 'dict'> |         100.0         |
# |            heritage           |        2         |          0.0          | <class 'str'>  |         100.0         |
# |          playground_1         |        1         |          0.0          | <class 'str'>  |         100.0         |
# |          playground_2         |        1         |          0.0          | <class 'str'>  |         100.0         |
# |             trees             |        2         |          0.0          | <class 'str'>  |         100.0         |
# |         protect_class         |        71        |          0.01         | <class 'str'>  |         100.0         |
# |        protection_title       |        71        |          0.01         | <class 'str'>  |         100.0         |
# |              wood             |        1         |          0.0          | <class 'str'>  |         100.0         |
# |          city_served          |        1         |          0.0          | <class 'str'>  |         100.0         |
# |              iata             |        3         |          0.0          | <class 'str'>  |         100.0         |
# |     international_flights     |        1         |          0.0          | <class 'str'>  |         100.0         |
# |              wall             |        4         |          0.0          | <class 'str'>  |         100.0         |
# |            open_air           |        1         |          0.0          | <class 'str'>  |         100.0         |
# |             basin             |        5         |          0.0          | <class 'str'>  |         100.0         |
# |             police            |        1         |          0.0          | <class 'str'>  |         100.0         |
# |          closest_city         |        1         |          0.0          | <class 'str'>  |         100.0         |
# |           restaurant          |        1         |          0.0          | <class 'str'>  |         100.0         |
# |             tidal             |        3         |          0.0          | <class 'str'>  |         100.0         |
# |            seasonal           |        2         |          0.0          | <class 'str'>  |         100.0         |
# |            product            |        2         |          0.0          | <class 'str'>  |         100.0         |
# |           step_count          |        2         |          0.0          | <class 'str'>  |         100.0         |
# |             paved             |        1         |          0.0          | <class 'str'>  |         100.0         |
# |         changing_table        |        1         |          0.0          | <class 'str'>  |         100.0         |
# |            culvert            |        1         |          0.0          | <class 'str'>  |         100.0         |
# |        fitness_station        |        1         |          0.0          | <class 'str'>  |         100.0         |
# |          water_source         |        1         |          0.0          | <class 'str'>  |         100.0         |
# |           check_date          |        2         |          0.0          | <class 'str'>  |         100.0         |
# |             resort            |        1         |          0.0          | <class 'str'>  |         100.0         |
# |              bin              |        2         |          0.0          | <class 'str'>  |         100.0         |
# |           truck_wash          |        2         |          0.0          | <class 'str'>  |         100.0         |
# |          member_refs          |       963        |          0.08         | <class 'list'> |         100.0         |
# |             e-road            |        3         |          0.0          | <class 'dict'> |         100.0         |
# |             route             |       193        |          0.02         | <class 'str'>  |         100.0         |
# |           ISO3166-1           |        2         |          0.0          | <class 'dict'> |         100.0         |
# |        default_language       |        2         |          0.0          | <class 'str'>  |         100.0         |
# |         official_name         |        3         |          0.0          | <class 'dict'> |         100.0         |
# |            timezone           |        2         |          0.0          | <class 'str'>  |         100.0         |
# |              TMC              |        1         |          0.0          | <class 'dict'> |         100.0         |
# |           ISO3166-2           |        7         |          0.0          | <class 'str'>  |         100.0         |
# |              from             |        12        |          0.0          | <class 'str'>  |         100.0         |
# |               to              |        13        |          0.0          | <class 'str'>  |         100.0         |
# |          restriction          |       104        |          0.01         | <class 'str'>  |         100.0         |
# |          related_law          |        1         |          0.0          | <class 'str'>  |         100.0         |
# |          castle_type          |        1         |          0.0          | <class 'str'>  |         100.0         |
# |          int_network          |        1         |          0.0          | <class 'str'>  |         100.0         |
# |           roundtrip           |        1         |          0.0          | <class 'str'>  |         100.0         |
# |          route_master         |        2         |          0.0          | <class 'str'>  |         100.0         |
# |           alternate           |        1         |          0.0          | <class 'str'>  |         100.0         |
# +-------------------------------+------------------+-----------------------+----------------+-----------------------+

# %%
# Set convenience constants
EXISTS = {"$exists": True}
NOT_NULL = lambda x: {"$ifNull": [ x, 0 ]}
NOT_NULL("test")
# Out:
# {'$ifNull': ['test', 0]}

# %%
# Count unique useres
len(sbg.distinct("created.uid"))
# Out:
# 815

# %%
# Count different classes of documents
pipeline = [{"$group": { "_id": "$class",
                        "count": {"$sum": 1}}},
            {"$sort": {"count": -1}}]
list(sbg.aggregate(pipeline))
# Out:
# [{'_id': 'node', 'count': 1097260},
#  {'_id': 'way', 'count': 120256},
#  {'_id': 'relation', 'count': 963},
#  {'_id': 'bounds', 'count': 1},
#  {'_id': 'osm', 'count': 1},
#  {'_id': 'meta', 'count': 1},
#  {'_id': 'note', 'count': 1}]

# %%
sbg.count_documents({"power": EXISTS})
# Out:
# 11838

# %%
## Question 3.1 - Explore types fields related to power
pipeline = [{"$match": {"power": EXISTS}},
            {"$group": { "_id": "$power",
                        "count": {"$sum": 1}}},
            {"$sort": {"count": -1}}]
list(sbg.aggregate(pipeline))
# Out:
# [{'_id': 'tower', 'count': 5873},
#  {'_id': 'pole', 'count': 4714},
#  {'_id': 'minor_line', 'count': 662},
#  {'_id': 'transformer', 'count': 292},
#  {'_id': 'line', 'count': 185},
#  {'_id': 'substation', 'count': 74},
#  {'_id': 'generator', 'count': 27},
#  {'_id': 'plant', 'count': 5},
#  {'_id': 'portal', 'count': 3},
#  {'_id': 'terminal', 'count': 1},
#  {'_id': 'yes', 'count': 1},
#  {'_id': 'pole;tower', 'count': 1}]

# %%
## Question 3.1 - Count source of the power when plant or generator
pipeline = [{"$match": {"$or":[ {"power": 'generator'},
                                {"power": 'plant'}]}},
            {"$project":  {"power": 1,
                           "source": {"$ifNull": ["$generator.source",
                                                "$plant.source"]}}},
            {"$group": { "_id": "$source",
                        "count": {"$sum": 1}}},
            {"$sort": {"count": -1}}]
list(sbg.aggregate(pipeline))
# Out:
# [{'_id': 'solar', 'count': 17},
#  {'_id': 'hydro', 'count': 5},
#  {'_id': 'coal', 'count': 5},
#  {'_id': None, 'count': 4},
#  {'_id': 'gas', 'count': 1}]

# %%
## Question 3.1 - Explore if it is possible to calculate the total output of each source
pipeline = [{"$match": {"$or":[ {"power": 'generator'},
                                {"power": 'plant'}]}},
            {"$project":  {"power": 1,
                           "name": 1,
                           "source": {"$ifNull": ["$generator.source",
                                                "$plant.source"]},
                          "output": {"$ifNull": ["$generator.output.electricity",
                                                "$plant.output.electricity"]}}}]
list(sbg.aggregate(pipeline))
# Out:
# [{'_id': ObjectId('5f2d4c56f80d478f6f221dcf'),
#   'name': {'local': 'ВЕЦ "Асеница"'},
#   'power': 'generator',
#   'source': 'hydro',
#   'output': '7 MW'},
#  {'_id': ObjectId('5f2d4c57f80d478f6f249958'),
#   'name': {'local': 'ВЕЦ "Асеница 1"'},
#   'power': 'generator',
#   'source': 'hydro',
#   'output': '7 MW'},
#  {'_id': ObjectId('5f2d4c57f80d478f6f249959'),
#   'name': {'local': 'ВЕЦ "Студен кладенец"'},
#   'power': 'generator',
#   'source': 'hydro',
#   'output': '90 MW'},
#  {'_id': ObjectId('5f2d4c59f80d478f6f29c7a6'),
#   'name': {'local': 'Блок 1'},
#   'power': 'generator',
#   'source': 'coal',
#   'output': '345 MW'},
#  {'_id': ObjectId('5f2d4c59f80d478f6f29c7a7'),
#   'name': {'local': 'Блок 2'},
#   'power': 'generator',
#   'source': 'coal',
#   'output': '345 MW'},
#  {'_id': ObjectId('5f2d4c5af80d478f6f2bdd72'),
#   'name': {'local': 'МВЕЦ "Десислава"'},
#   'power': 'generator',
#   'source': 'hydro'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f31dfc5'),
#   'name': {'local': 'ТЕЦ "Север"'},
#   'power': 'generator',
#   'source': 'coal'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f3215a8'),
#   'name': {'local': 'TPP AES Galabovo'},
#   'power': 'plant',
#   'source': 'coal',
#   'output': '370 MW'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f3215d4'),
#   'name': {'local': 'Фотоволтаична централа'},
#   'power': 'generator',
#   'source': 'solar'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f321760'),
#   'name': {'local': 'Марица Изток 3', 'English': 'Maritsa Iztok 3'},
#   'power': 'plant',
#   'source': 'coal',
#   'output': '908 MW'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f321a7a'),
#   'name': {'local': 'ВЕЦ Кърджали'},
#   'power': 'plant',
#   'source': 'hydro',
#   'output': '106.4 MW'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f322617'),
#   'name': {'local': 'Фотоволтаична централа'},
#   'power': 'generator',
#   'source': 'solar'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f322618'),
#   'name': {'local': 'Фотоволтаична централа'},
#   'power': 'generator',
#   'source': 'solar'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f32274e'),
#   'name': {'local': 'Фотоволтаична централа'},
#   'power': 'generator',
#   'source': 'solar'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f32344c'),
#   'name': {'local': 'Фотоволтаична централа'},
#   'power': 'generator',
#   'source': 'solar',
#   'output': 'yes'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f32344d'),
#   'name': {'local': 'Фотоволтаична централа'},
#   'power': 'generator',
#   'source': 'solar'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f324d7c'),
#   'name': {'local': 'Фотоволтаична ел.централа'},
#   'power': 'generator'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f32a5c3'),
#   'power': 'generator',
#   'source': 'solar'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f32a70a'),
#   'name': {'local': 'Solar energy plant'},
#   'power': 'generator'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f32b346'),
#   'power': 'generator',
#   'source': 'solar'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f32cd5e'),
#   'power': 'generator',
#   'source': 'solar',
#   'output': 'yes'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f32cd5f'),
#   'power': 'generator',
#   'source': 'solar',
#   'output': 'yes'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f32cd60'),
#   'power': 'generator',
#   'source': 'solar',
#   'output': 'yes'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f32cd61'),
#   'power': 'generator',
#   'source': 'solar',
#   'output': 'yes'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f32cdf6'),
#   'power': 'generator',
#   'source': 'solar',
#   'output': 'yes'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f32e8d4'),
#   'name': {'local': 'Фотоволтаична електроцентрала'},
#   'power': 'generator',
#   'source': 'solar'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f332c41'), 'power': 'generator'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f332c66'), 'power': 'plant'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f33579a'),
#   'name': {'local': 'Соларен парк "България" АД'},
#   'power': 'generator',
#   'source': 'solar',
#   'output': '5 MW'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f3366db'),
#   'power': 'generator',
#   'source': 'solar'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f337e3c'),
#   'name': {'local': 'ТЕЦ Юг'},
#   'power': 'plant',
#   'source': 'gas'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f3389a5'),
#   'power': 'generator',
#   'source': 'solar',
#   'output': 'yes'}]

# %%
##Question 3.2 Count the different entities which have a website
# different types of objects (with different schemas) can have a website
pipeline = [{"$match": {"class": "node",
                        "website": EXISTS}},
            {"$project": {"entity": {"$switch": {"branches": [  {"case": NOT_NULL("$amenity"),
                                                                 "then": "$amenity"},
                                                                {"case": NOT_NULL("$shop"),
                                                                 "then": {"$concat": [{"$cond": [{"$eq": ["$shop",
                                                                                                          'yes']},
                                                                                                 "",
                                                                                                 "$shop"]},
                                                                                      " ",
                                                                                      "shop"]}},
                                                                {"case": NOT_NULL("$place"),
                                                                 "then": "$place"},
                                                                {"case": NOT_NULL("$tourism"),
                                                                 "then": "$tourism"},
                                                                {"case": NOT_NULL("$office"),
                                                                 "then": "office"}],
                                                 "default": None}}}},
            {"$group": { "_id": "$entity",
                        "count": {"$sum": 1}}},
            {"$match": {"count": {"$gte": 5}}},
            {"$sort": {"count": -1}}]
list(sbg.aggregate(pipeline))
# Out:
# [{'_id': None, 'count': 73},
#  {'_id': 'restaurant', 'count': 24},
#  {'_id': 'clothes shop', 'count': 21},
#  {'_id': 'office', 'count': 19},
#  {'_id': 'dentist', 'count': 17},
#  {'_id': 'hotel', 'count': 16},
#  {'_id': 'car_repair shop', 'count': 11},
#  {'_id': 'bank', 'count': 11},
#  {'_id': ' shop', 'count': 9},
#  {'_id': 'post_office', 'count': 5},
#  {'_id': 'supermarket shop', 'count': 5}]

# %%
#Q3.2 further exploration - how many of the restaurants have website
pipeline = [{"$match": {"amenity": "restaurant"}},
            {"$project": { "has_website": {"$convert": {"input": "$website",
                                                        "to": "bool" }}}},
            {"$group": {"_id": "$has_website",
                        "count": {"$sum": 1}}},
            {"$project": {"has_website": "$_id", "count": 1, "_id": 0}}]
list(sbg.aggregate(pipeline))
# Out:
# [{'count': 27, 'has_website': True}, {'count': 352, 'has_website': None}]

# %%
#Q3.2 further exploration - what other entities have websites
list(sbg.find({"website": EXISTS,
               "amenity": {"$exists": False},
               "place": {"$exists": False},
               "amenity": {"$exists": False},
                "shop": {"$exists": False},
              "tourism": {"$exists": False},
              "office": {"$exists": False} }))
# Out:
# [{'_id': ObjectId('5f2d4c57f80d478f6f2510e6'),
#   'class': 'node',
#   'pos': [42.1510102, 24.7460763],
#   'id': '2072147024',
#   'created': {'version': '4',
#    'timestamp': '2019-03-23T23:11:52Z',
#    'changeset': '68457555',
#    'uid': '9451067',
#    'user': 'b-jazz-bot'},
#   'address': {'housenumber': '53', 'postcode': 4000},
#   'name': {'local': 'Idea Studio Ltd.'},
#   'name_1': 'idea studio',
#   'operator': 'Borislav Arapchev',
#   'source': 'office',
#   'website': 'https://www.ideabg.com/'},
#  {'_id': ObjectId('5f2d4c5af80d478f6f2b3f56'),
#   'class': 'node',
#   'pos': [42.125432, 24.7411632],
#   'id': '4432811902',
#   'created': {'version': '1',
#    'timestamp': '2016-10-05T14:40:00Z',
#    'changeset': '42659407',
#    'uid': '4678925',
#    'user': 'BorjaBobby'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '48',
#    'street': 'бул. Македония'},
#   'name': {'local': 'Автостъкла Кобра'},
#   'phone': '+359884351001',
#   'website': 'http://www.autoglass.bg/bg'},
#  {'_id': ObjectId('5f2d4c5af80d478f6f2b4aeb'),
#   'class': 'node',
#   'pos': [41.9324217, 25.5571874],
#   'id': '4458682490',
#   'created': {'version': '2',
#    'timestamp': '2016-11-24T19:09:26Z',
#    'changeset': '43929039',
#    'uid': '150201',
#    'user': 'plamen'},
#   'historic': 'monument',
#   'name': {'local': 'Паметник на завистта (Българският Икар)',
#    'English': 'Monument of Envy'},
#   'website': 'http://poseti.guide-bulgaria.com/a/1314/pametnikat_na_zavistta__bulgarskiat_ikar.htm'},
#  {'_id': ObjectId('5f2d4c5af80d478f6f2b50a2'),
#   'class': 'node',
#   'pos': [42.011913, 24.8706063],
#   'id': '4484088289',
#   'created': {'version': '5',
#    'timestamp': '2018-12-21T05:47:52Z',
#    'changeset': '65659535',
#    'uid': '150201',
#    'user': 'plamen'},
#   'address': {'city': 'Асеновград',
#    'postcode': 4230,
#    'street': 'ул. Цар Освободител 22'},
#   'description': 'резачки, косачки, тримери, водни помпи',
#   'name': {'local': 'STIHL - магазин (АРВА-2008)'},
#   'phone': '0888 45 29 11',
#   'website': 'https://arva.bg'},
#  {'_id': ObjectId('5f2d4c5af80d478f6f2b50a3'),
#   'class': 'node',
#   'pos': [42.100792, 25.2249464],
#   'id': '4484096935',
#   'created': {'version': '4',
#    'timestamp': '2020-03-31T16:30:21Z',
#    'changeset': '82881174',
#    'uid': '150201',
#    'user': 'plamen'},
#   'address': {'city': 'Първомай', 'street': 'ул. Братя Миладинови Север 17А'},
#   'name': {'local': 'STIHL - магазин, агроаптека'},
#   'phone': '+359888452911',
#   'website': 'https://arva.bg'},
#  {'_id': ObjectId('5f2d4c5af80d478f6f2b63f6'),
#   'class': 'node',
#   'pos': [42.1522795, 24.7346618],
#   'id': '4566916148',
#   'created': {'version': '1',
#    'timestamp': '2016-12-22T13:38:43Z',
#    'changeset': '44591002',
#    'uid': '5005477'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '14',
#    'street': 'ул. Георги Комитата'},
#   'name': {'local': 'Декоративни, интериорни и екстериорни бои Пловдив "Европа Пейнт ЕООД”'},
#   'website': 'www.tambour.bg'},
#  {'_id': ObjectId('5f2d4c5af80d478f6f2b674e'),
#   'class': 'node',
#   'pos': [42.1597422, 24.7478625],
#   'id': '4594114982',
#   'created': {'version': '2',
#    'timestamp': '2017-07-29T16:57:51Z',
#    'changeset': '50676375',
#    'uid': '6362593',
#    'user': 'BLADE777'},
#   'address': {'city': 'Plovdiv',
#    'housenumber': '22',
#    'street': 'ул. Бул.Цар Борис IIIII Обединител'},
#   'name': {'local': 'Железария и Ел. Материяли Пловдив Магазин Роси'},
#   'website': 'www.rosi-995.com'},
#  {'_id': ObjectId('5f2d4c5af80d478f6f2b77f9'),
#   'class': 'node',
#   'pos': [42.1121073, 24.7605284],
#   'id': '4742847402',
#   'created': {'version': '2',
#    'timestamp': '2017-06-05T07:09:42Z',
#    'changeset': '49259861',
#    'uid': '4967304'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '18',
#    'street': 'ул. Кукленско Шосе'},
#   'description': 'https://business.google.com/b/104372391644205204779/dashboard/l/14126786100660129278?hl=bg&ppsrc=GMBLR&gmbsrc=bg-bg-et-gs-z-gmb-l-z-h~my|redirect|u&utm_campaign=bg-bg-et-gs-z-gmb-l-z-h~my|redirect|u&utm_medium=et&utm_source=gmb',
#   'email': 'oyroshpedad@gmail.com',
#   'name': {'local': 'Куриерски услуги и транспорт Пловдив Ойрошпед АД'},
#   'phone': '0700 19991',
#   'website': 'http://www.eurosped.bg'},
#  {'_id': ObjectId('5f2d4c5af80d478f6f2b77fa'),
#   'class': 'node',
#   'pos': [42.1579725, 24.732907],
#   'id': '4742981381',
#   'created': {'version': '1',
#    'timestamp': '2017-03-19T12:45:13Z',
#    'changeset': '46981272',
#    'uid': '5516489'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '111',
#    'street': 'бул. България'},
#   'email': 'yord.nikolova17@gmail.com',
#   'name': {'local': 'Строителство, изграждане, ремонт и поддръжка на Генератори Пловдив "Йолани”'},
#   'website': 'https://yolanibg.com'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2d7af0'),
#   'class': 'node',
#   'pos': [42.1187778, 24.7148253],
#   'id': '5277530510',
#   'created': {'version': '1',
#    'timestamp': '2017-12-11T12:48:49Z',
#    'changeset': '54538850',
#    'uid': '7206519',
#    'user': 'asglight'},
#   'description': 'ASG light е търговска марка от 2012 година, като основната ѝ дейност е асемблиране на печатни платки и възобновяема енергия. Още през 2013 съсредоточават производството си към LED осветление - производство и проектиране. ',
#   'email': 'info@asglight.bg',
#   'name': {'local': 'Индустриално лед осветление от ASGLight'},
#   'phone': '0889 121 312',
#   'website': 'http://asglight.bg/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2d9bf4'),
#   'class': 'node',
#   'pos': [42.1516847, 24.7735808],
#   'id': '5426501706',
#   'created': {'version': '1',
#    'timestamp': '2018-02-21T12:33:11Z',
#    'changeset': '56547954',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '256',
#    'street': 'ул. 6-Ти Септември'},
#   'building': 'yes',
#   'description': 'парапети, навеси и метални конструкции',
#   'name': {'local': 'АлуГруп(AluGroup)'},
#   'phone': '088 331 2342',
#   'website': 'http://www.alugroup.bg/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2d9bf5'),
#   'class': 'node',
#   'pos': [42.1604646, 24.7691387],
#   'id': '5426641803',
#   'created': {'version': '1',
#    'timestamp': '2018-02-21T13:33:39Z',
#    'changeset': '56549695',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '1',
#    'postcode': 4003,
#    'street': 'ул. Рогошко Шосе'},
#   'description': 'Фирма „Декорал Спектър” ЕООД гр.Пловдив е новоучредена фирма за електростатично прахаво боядисване  на всички видове алуминиеви и стоманени профили, изделия от метални конструкции, LT ламарина, огради,парапети, алуминиеви и метални ПЕРГОЛИ и много други.',
#   'name': {'local': 'Прахово боядисване Декорал Спектър ЕООД'},
#   'phone': '088 674 4232',
#   'website': 'http://www.prahovo-plovdiv.com'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2da208'),
#   'class': 'node',
#   'pos': [42.1544759, 24.7058377],
#   'id': '5430931382',
#   'created': {'version': '1',
#    'timestamp': '2018-02-23T08:56:53Z',
#    'changeset': '56602943',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив', 'street': 'бул. България'},
#   'building': 'yes',
#   'description': 'Озеленяване -затревяване с тревен чим или хидропосев,поддържане - косене, аериране, торене, оформяне храсти и корона на дървета.',
#   'name': {'local': 'Интерторго'},
#   'phone': '088 876 0857',
#   'website': 'http://ozelenitel.eu/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2da392'),
#   'class': 'node',
#   'pos': [42.1611301, 24.7683248],
#   'id': '5466207708',
#   'created': {'version': '2',
#    'timestamp': '2019-03-23T23:11:49Z',
#    'changeset': '68457555',
#    'uid': '9451067',
#    'user': 'b-jazz-bot'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '6',
#    'postcode': 4003,
#    'street': 'ул. Рогошко Шосе'},
#   'description': 'Веси Колор предлага прахово боядисване на всякакъв вид метални и алуминиеви профили и конструкции. Голяма гама избор на цветове, текстури, шагрени, саблета. Височина на пеща 3,40 см., ширина на пеща 1,20 см. и дължина 6,30 см.',
#   'name': {'local': 'Прахово боядисване -Веси Колор'},
#   'phone': '089 753 3318',
#   'website': 'https://vesycolor.business.site/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2da423'),
#   'class': 'node',
#   'pos': [42.0307639, 24.8411961],
#   'id': '5480022148',
#   'created': {'version': '1',
#    'timestamp': '2018-03-15T10:05:04Z',
#    'changeset': '57205395',
#    'uid': '6176812'},
#   'address': {'city': 'Асеновград',
#    'housenumber': '103',
#    'street': 'ул. Ул. Захария'},
#   'building': 'yes',
#   'description': 'Внос и дистрибуция на мокри кърпи, санитарно-хигиенни материали и козметични продукти.',
#   'name': {'local': 'Склад за мокри кърпи - Сева Трейд'},
#   'phone': '088 882 7146',
#   'website': 'www.sevatrade.com'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2dab03'),
#   'class': 'node',
#   'pos': [42.1183977, 24.7446622],
#   'id': '5513068051',
#   'created': {'version': '1',
#    'timestamp': '2018-03-29T06:13:05Z',
#    'changeset': '57621249',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '5',
#    'street': 'ул. Александър Стамболийски'},
#   'building': 'yes',
#   'description': 'Основната ни дейност е сериграфията - ситопечат. Този вид печат е уникален със своите възможности. Пресъздава наситени и "живи" цветове, върху почти всякакви повърхности – хартия, картон, PVC, PP, PE, плексиглас, плат, стъкло, керемика, метал, дърво и др.',
#   'email': 'office@aveprint.bg',
#   'fax': '032 210266',
#   'name': {'local': 'Ситопечат Аве Принт'},
#   'phone': '032 210214',
#   'website': 'www.aveprint.bg'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2db0b7'),
#   'class': 'node',
#   'pos': [42.1564904, 24.7745908],
#   'id': '5527250889',
#   'created': {'version': '1',
#    'timestamp': '2018-04-04T08:38:20Z',
#    'changeset': '57795534',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив', 'housenumber': '186', 'street': 'ул. Марица'},
#   'building': 'yes',
#   'description': '2Р България е българска компания с над 20 годишно присъствие на пазара. Основната дейност е\nпроизводство и търговия с осветителни тела, елементи за тях, производство на стълбове за улично и\nпарково осветление.',
#   'name': {'local': '2Р България ЕООД'},
#   'phone': '032 630 923',
#   'website': 'https://www.2r-bg.com/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2db0b8'),
#   'class': 'node',
#   'pos': [42.1369232, 24.7158709],
#   'id': '5527339540',
#   'created': {'version': '1',
#    'timestamp': '2018-04-04T09:07:12Z',
#    'changeset': '57796371',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '66',
#    'postcode': 4000,
#    'street': 'бул. Пещерско Шосе'},
#   'description': 'Свежен търгува с интериорен текстил на едро и дребно. Фирмата е вносител на разнообразни битови текстилни изделия, както и хотелски и ресторантски текстил. Можете да поръчате изделия по индивидуални изисквания - размери, цветове, материи.',
#   'name': {'local': 'Свежен'},
#   'phone': '0879 64 06 89',
#   'website': 'http://svejen-tex.com/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2dbc4b'),
#   'class': 'node',
#   'pos': [42.1717412, 24.7527644],
#   'id': '5564450399',
#   'created': {'version': '1',
#    'timestamp': '2018-04-19T13:57:54Z',
#    'changeset': '58234284',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '145',
#    'postcode': 4003,
#    'street': 'ул. Брезовско Шосе'},
#   'building': 'yes',
#   'description': 'Директен внос и търговия на осветителна техника за дома и офиса:\n♦ Обзавеждане на административни сгради, промишлени халета и хотели \n♦ Богата гама LED осветители \n♦ Енергоспестяващи крушки \n♦ Светещи линии \n♦ Красиви подаръци и сувенири',
#   'name': {'local': 'Сити Лайт ООД'},
#   'phone': '089 544 8356',
#   'website': 'http://city-lights-bg.com/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2dd241'),
#   'class': 'node',
#   'pos': [42.1367213, 24.7416191],
#   'id': '5604932891',
#   'created': {'version': '1',
#    'timestamp': '2018-05-08T17:10:36Z',
#    'changeset': '58794689',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '2',
#    'street': 'ул. Васил Априлов'},
#   'building': 'yes',
#   'description': 'Ние сме компания, чиято основна дейност е разработване, внедряване, поддържане, интегриране, адаптация и усъвършенстване на Системи за управление в съответствие с изискванията на Международните мениджърски стандарти.',
#   'name': {'local': 'Стандарти Iso Professional Consult Ltd'},
#   'phone': '089 431 9643',
#   'website': 'http://iso-bg.org/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2de71e'),
#   'class': 'node',
#   'pos': [42.1572131, 24.7759874],
#   'id': '5657030446',
#   'created': {'version': '1',
#    'timestamp': '2018-06-01T18:43:31Z',
#    'changeset': '59469354',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив', 'street': 'ул. Марица'},
#   'building': 'yes',
#   'description': 'Вносител на органични и минерални торове от Испания.',
#   'name': {'local': 'Минерални торове Агрокомерсио ЕООД'},
#   'phone': '087 913 0147',
#   'website': 'http://jisa.es/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2de74c'),
#   'class': 'node',
#   'pos': [42.1618847, 24.747133],
#   'id': '5675896787',
#   'created': {'version': '1',
#    'timestamp': '2018-06-08T16:29:48Z',
#    'changeset': '59673505',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '12',
#    'street': 'ул. Бул.Цар Борис IIIII Обединител'},
#   'building': 'yes',
#   'description': 'Учебен център „АВТОКОНСУЛТ – 2000”,Пловдив обучава водачи от категории: В, В 78 на автоматик, С, СЕ, Д.',
#   'name': {'local': 'Автоконсулт - 2000 ЕООД'},
#   'phone': '089 874 4895',
#   'website': 'http://avtokonsult2000.com/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2de750'),
#   'class': 'node',
#   'pos': [42.1360507, 24.7597941],
#   'id': '5688466812',
#   'created': {'version': '2',
#    'timestamp': '2019-04-03T11:55:03Z',
#    'changeset': '68834923',
#    'uid': '9451067',
#    'user': 'b-jazz-bot'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '130',
#    'street': 'ул. Булевард Христо Ботев'},
#   'building': 'yes',
#   'description': 'Услугата, която предлагаме е поставяне на орехов паркет.',
#   'name': {'local': 'Орехов паркет - DP parquet'},
#   'phone': '089 587 8546',
#   'website': 'https://dp-parquet.business.site/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2de751'),
#   'class': 'node',
#   'pos': [42.1207626, 24.7072666],
#   'id': '5688472501',
#   'created': {'version': '2',
#    'timestamp': '2019-03-20T16:44:52Z',
#    'changeset': '68343529',
#    'uid': '9451067',
#    'user': 'b-jazz-bot'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '168',
#    'street': 'ул. Коматевско Шосе'},
#   'building': 'yes',
#   'description': 'Пълна инженерингова и консултантска дейност, сервиз и обучение в областта на водообработката за енергийния сектор и промишлеността.',
#   'name': {'local': 'Пречистване на води | Хидро-Хикс-България ООД'},
#   'phone': '032 677 394',
#   'website': 'https://hydro-x-bg.com/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2de752'),
#   'class': 'node',
#   'pos': [42.122287, 24.7537937],
#   'id': '5688477616',
#   'created': {'version': '1',
#    'timestamp': '2018-06-13T17:38:12Z',
#    'changeset': '59818008',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив', 'street': 'бул. Никола Вапцаров'},
#   'building': 'yes',
#   'description': 'Компетентна помощ при избора на най-подходящите компоненти и цялостни решения в областта на индустриалната автоматизация.\nМонтаж и пускане в експлоатация на доставените машини и апарати.\nГаранционен и следгаранционен сервиз на доставеното оборудване.',
#   'name': {'local': 'Райкос Тех ЕООД'},
#   'phone': '032 596 972',
#   'website': 'http://www.raikostech.com/kontakti/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2df8c9'),
#   'class': 'node',
#   'pos': [42.1427956, 24.7279419],
#   'id': '5736425537',
#   'created': {'version': '2',
#    'timestamp': '2018-07-03T12:01:03Z',
#    'changeset': '60376838',
#    'uid': '8499102',
#    'user': 'Flashgate'},
#   'address': {'city': 'Централен',
#    'housenumber': '35',
#    'postcode': 4002,
#    'street': 'бул. Свобода'},
#   'description': 'Flashgate Ltd предлага професионално фотозаснемане на::сватби, пред- и следсватбени фотосесии, семейни и лични фотосесии, както и всякакви бизнес събития и фирмени проекти на територията на Пловдив и цялата страна. Топ услуги и топ фотограф Юлиян Маринов!',
#   'email': 'flashgateltd@gmail.com',
#   'name': {'local': 'Flashgate Ltd'},
#   'note': 'VATnumber: BG205029164',
#   'payment': {'cash': 'yes'},
#   'phone': '+359889007203',
#   'website': 'https://www.flashgate.co/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2df8f3'),
#   'class': 'node',
#   'pos': [41.8467585, 26.0782905],
#   'id': '5737005799',
#   'created': {'version': '1',
#    'timestamp': '2018-07-03T17:02:07Z',
#    'changeset': '60385037',
#    'uid': '6176812'},
#   'address': {'city': 'Любимец',
#    'housenumber': '30',
#    'street': 'ул. Републиканска'},
#   'building': 'yes',
#   'description': 'Боуен терапията служи като средство да трансформирате собствените си преживявания чрез телата си и отключва капацитет да се излекувате.\n',
#   'name': {'local': 'Боуен Терапия'},
#   'phone': '088 542 1842',
#   'website': 'http://bowenbg.bg/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2df8f4'),
#   'class': 'node',
#   'pos': [42.1071607, 24.7038891],
#   'id': '5739304374',
#   'created': {'version': '1',
#    'timestamp': '2018-07-04T15:35:18Z',
#    'changeset': '60412569',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '27',
#    'street': 'ул. Бадемите'},
#   'building': 'yes',
#   'description': 'Мобилен сервиз и услуги за пътна помощ 24/7 в Пловдив.',
#   'name': {'local': 'АУТО ДИ 73 ЕООД'},
#   'phone': '087 687 8979',
#   'website': 'https://247-autorepairshop.business.site/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2dfc41'),
#   'class': 'node',
#   'pos': [42.0783343, 24.7527734],
#   'id': '5749963306',
#   'created': {'version': '2',
#    'timestamp': '2018-07-09T18:46:00Z',
#    'changeset': '60549607',
#    'uid': '8525148',
#    'user': 'bojinov'},
#   'address': {'city': 'Браниполе',
#    'housenumber': '6',
#    'postcode': 4109,
#    'street': 'ул. Съединение'},
#   'description': 'Фирма за комунални услуги.\nОтпушване на канализации;\nПочистване на септични ями;\nОтводняване;\nПоддръжка на канализационни мрежи.',
#   'email': 'bojinov_66@gmail.com',
#   'fixme': 'Браниполе, общ. Родопи, обл. Пловдив',
#   'name': {'local': 'БОЖИНОВ 2006'},
#   'name_1': 'Георги Божинов',
#   'phone': '+359 887 550735',
#   'website': 'http://kanal-otpushva.com/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2dfc43'),
#   'class': 'node',
#   'pos': [42.1546225, 24.7766861],
#   'id': '5754177404',
#   'created': {'version': '1',
#    'timestamp': '2018-07-11T14:18:36Z',
#    'changeset': '60617884',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив', 'housenumber': '7', 'street': 'ул. Владая'},
#   'building': 'yes',
#   'description': 'Дейноста на фирмата е производство, търговия, монтаж на парапети.',
#   'name': {'local': '"БАРОС ВИЖЪН" ЕООД'},
#   'phone': '087 917 2585',
#   'website': 'http://www.barosvision.com/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2dfc45'),
#   'class': 'node',
#   'pos': [42.1407605, 24.7404423],
#   'id': '5755901231',
#   'created': {'version': '1',
#    'timestamp': '2018-07-12T10:07:08Z',
#    'changeset': '60645833',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '2',
#    'street': 'бул. Любен Каравелов'},
#   'building': 'yes',
#   'description': 'Денонощна Детска Поликлиника Вела е специализирано здравно заведение с денонощен, безотказен ритъм на работа, създадена за доболнично лечение и профилактика на детските заболявания  от  първите дни след раждането на детето до  неговото израстване.',
#   'name': {'local': 'Детска Клиника - Велаклиник'},
#   'phone': '087 864 1919',
#   'website': 'http://velaclinic.com/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2dfc46'),
#   'class': 'node',
#   'pos': [42.1551026, 24.7369156],
#   'id': '5755925424',
#   'created': {'version': '1',
#    'timestamp': '2018-07-12T10:12:16Z',
#    'changeset': '60646020',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '9',
#    'street': 'ул. Порто Лагос'},
#   'building': 'yes',
#   'description': 'Атлантис разработва и произвежда\n• Високоенергийни диодни лазери - дентални\n• Терапевтични лазери\n• Дентална диагностична апаратурa',
#   'name': {'local': 'Атлантис ООД'},
#   'phone': '032 962 136',
#   'website': 'http://www.laser-atlantis.com/main/index.html'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2dfc47'),
#   'class': 'node',
#   'pos': [42.0634709, 24.741598],
#   'id': '5755929575',
#   'created': {'version': '1',
#    'timestamp': '2018-07-12T10:14:13Z',
#    'changeset': '60646077',
#    'uid': '6176812'},
#   'address': {'city': 'Брестник'},
#   'building': 'yes',
#   'description': 'Фирма ,,МИРАЙ 98 ‘‘ООД  е създадена през 1998г. като фирма вносител на професионално кухненско и ресторантско оборудване.',
#   'name': {'local': 'Мирай 98 ООД'},
#   'phone': '032 503 220',
#   'website': 'http://www.miray98.com/contact'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2dfc48'),
#   'class': 'node',
#   'pos': [42.1744794, 24.7509746],
#   'id': '5755942030',
#   'created': {'version': '1',
#    'timestamp': '2018-07-12T10:18:27Z',
#    'changeset': '60646216',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив', 'housenumber': '84', 'street': 'ул. Полет'},
#   'building': 'yes',
#   'description': 'Основен предмет на дейност – Търговия на едро с железария, ел. материали,',
#   'name': {'local': 'Мерт М ЕООД'},
#   'phone': '087 850 5408',
#   'website': 'mert.bg'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2dfc4a'),
#   'class': 'node',
#   'pos': [42.1360208, 24.7542764],
#   'id': '5755956977',
#   'created': {'version': '2',
#    'timestamp': '2019-03-23T23:10:21Z',
#    'changeset': '68457531',
#    'uid': '9451067',
#    'user': 'b-jazz-bot'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '92',
#    'street': 'бул. Христо Ботев'},
#   'building': 'yes',
#   'description': 'Артра® - уникални идеи, иновативни повърхности! Претворяваме в реалност вашата творческа визия посредством арт проекти, картини, пана, интериорни елементи и повърхности.',
#   'name': {'local': 'Артра'},
#   'phone': '089 844 8218',
#   'website': 'https://artra.bg/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2dfcb2'),
#   'class': 'node',
#   'pos': [42.1446006, 24.7414079],
#   'id': '5768730353',
#   'created': {'version': '1',
#    'timestamp': '2018-07-18T17:07:35Z',
#    'changeset': '60844030',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив', 'housenumber': '52', 'street': 'бул. Руски'},
#   'building': 'yes',
#   'description': 'Цялостно изграждане на нови покриви.\nСмяна на капандура.\nПренареждане на керемиди.\nЧастични покривни ремонти.',
#   'name': {'local': 'Хидроизолация и ремонт на покриви'},
#   'phone': '089 646 5588',
#   'website': 'http://remonti-pokrivi1.com/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2dfcb4'),
#   'class': 'node',
#   'pos': [42.1367205, 24.7535356],
#   'id': '5770543595',
#   'created': {'version': '1',
#    'timestamp': '2018-07-19T13:21:26Z',
#    'changeset': '60872258',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '34',
#    'street': 'ул. Цар Асен'},
#   'building': 'yes',
#   'description': 'ДАФИНА ООД е легитимна, специализирана фирма за борба с вредните насекоми и гризачи.',
#   'name': {'local': 'Дафина ООД'},
#   'phone': '088 727 5803',
#   'website': 'https://janitorial-service-556.business.site/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2dfcb7'),
#   'class': 'node',
#   'pos': [41.931241, 25.5451766],
#   'id': '5776382856',
#   'created': {'version': '2',
#    'timestamp': '2019-04-03T12:01:22Z',
#    'changeset': '68835145',
#    'uid': '9451067',
#    'user': 'b-jazz-bot'},
#   'address': {'city': 'Хасково',
#    'housenumber': '65',
#    'street': 'ул. Добруджа'},
#   'building': 'yes',
#   'description': 'Мъжки и дамски спортни облекла.',
#   'phone': '088 790 2435',
#   'website': 'https://roteiro.eu/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2dfe60'),
#   'class': 'node',
#   'pos': [42.1324265, 24.7986769],
#   'id': '5830117185',
#   'created': {'version': '1',
#    'timestamp': '2018-08-13T16:45:26Z',
#    'changeset': '61632586',
#    'uid': '6176812'},
#   'address': {'city': 'Плодив',
#    'housenumber': 'бл.104',
#    'street': 'ул. Ж.К. Тракия'},
#   'building': 'yes',
#   'description': 'Славчо Карамфилов е завършил “Институт за учители - специалисти” - гр. Сливен през 1979 год. със специалност “ Преподавател – инструктор “.\nСлед това в продължение на 18 години е работил като инструктор в Съюза на българските автомобилисти ( СБА ) .',
#   'name': {'local': 'АВТОШКОЛА КАРАМФИЛОВ'},
#   'phone': '088 922 0654',
#   'website': 'http://avto-kursove.com/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2e02e5'),
#   'class': 'node',
#   'pos': [42.0983681, 24.7251368],
#   'id': '5868271550',
#   'created': {'version': '2',
#    'timestamp': '2019-03-23T23:08:27Z',
#    'changeset': '68457495',
#    'uid': '9451067',
#    'user': 'b-jazz-bot'},
#   'address': {'city': 'Пловдив', 'housenumber': '382', 'street': 'ул. Юг'},
#   'building': 'yes',
#   'description': 'Транспорт на пратки от Англия и Германия. ( Transport of parcels from Great Britain and Germany )',
#   'name': {'local': 'Gabieli Delivery Services'},
#   'phone': '098 894 5446',
#   'website': 'https://www.uktobg.com/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2e0ecc'),
#   'class': 'node',
#   'pos': [42.1524032, 24.745351],
#   'id': '5903350143',
#   'created': {'version': '2',
#    'timestamp': '2019-03-23T23:11:51Z',
#    'changeset': '68457555',
#    'uid': '9451067',
#    'user': 'b-jazz-bot'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '36',
#    'street': 'ул. Петко Каравелов'},
#   'building': 'yes',
#   'description': 'Фирмата предлага голям избор от шивашки материали: - камъни за вграждане, конци, ципове, сатенирани ленти, памучни ленти, спортни ленти, трикольор, органза, памучни ленти, панделки, еластични конци, конуси, макари, ширити, шнурове.',
#   'name': {'local': 'Шивашки материали Мазиар'},
#   'phone': '088 870 1618',
#   'website': 'https://www.maziarltd.com/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2e0ecd'),
#   'class': 'node',
#   'pos': [42.1237762, 24.7620859],
#   'id': '5903350216',
#   'created': {'version': '2',
#    'timestamp': '2018-12-14T06:17:07Z',
#    'changeset': '65462805',
#    'uid': '373200',
#    'user': 'Meglen'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '9',
#    'street': 'ул. Кукленско Шосе'},
#   'building': 'yes',
#   'description': ' лазерни технологии за обработка на детайли\n- водоструйни технологии за обработка на детайли\n- технологии за огъване на детайли\n- технологии за заваряване на детайли\n- инженерингова дейност в областта на обработката на детайли',
#   'name': {'local': 'Център За Лазерни Технологии ООД'},
#   'phone': '032 673 509',
#   'website': 'http://clt.bg/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2e0ece'),
#   'class': 'node',
#   'pos': [42.1562173, 24.7104897],
#   'id': '5905707689',
#   'created': {'version': '1',
#    'timestamp': '2018-09-14T06:36:55Z',
#    'changeset': '62572732',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '4',
#    'street': 'ул. Пазарджишко Шосе'},
#   'building': 'yes',
#   'description': 'Суровини за сладкарство и хлебопроизводство.',
#   'name': {'local': 'Суровини за сладкарство и хлебопроизводство | Хелас Хем Ад'},
#   'phone': '089 877 7018',
#   'website': 'https://warehouse-store-375.business.site/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2e1f61'),
#   'class': 'node',
#   'pos': [42.1504407, 24.7461054],
#   'id': '5940113265',
#   'created': {'version': '1',
#    'timestamp': '2018-09-30T06:27:51Z',
#    'changeset': '63054331',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '24',
#    'street': 'ул. Петко Каравелов'},
#   'building': 'yes',
#   'description': 'Фирмата предлага светещи букви и табели, тотеми, брандиране автомобили ,декориране на витрини с фолио, широкоформатен печат с високо качество, тениски по индивидуален дизайн, печатна реклама, индивидуални поръчки.',
#   'name': {'local': 'Арт Флекс ООД'},
#   'phone': '088 957 7775',
#   'website': 'http://reklamatabg.com/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2e2414'),
#   'class': 'node',
#   'pos': [42.1675735, 24.7333627],
#   'id': '5964128748',
#   'created': {'version': '1',
#    'timestamp': '2018-10-07T13:00:31Z',
#    'changeset': '63278554',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '9',
#    'street': 'ул. Георги Бенев'},
#   'building': 'yes',
#   'description': 'Внос и търговия със санитарно - хигиенни консумативи и оборудване на водещи марки в бранша: KIMBERLY CLARK, PAPERNET, BULKYSOFT, CLINEX и други. Производство на тоалетна хартия и кухненски ролки.',
#   'name': {'local': 'ЕвърКлийн ООД'},
#   'phone': '087 967 7911',
#   'website': 'http://evercleanbg.com/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2e2e04'),
#   'class': 'node',
#   'pos': [42.1287454, 24.7435206],
#   'id': '5988359371',
#   'created': {'version': '1',
#    'timestamp': '2018-10-16T07:21:14Z',
#    'changeset': '63566116',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '53',
#    'street': 'бул. Македония'},
#   'building': 'yes',
#   'description': 'Организация с дейност специализирана в сферата на недвижимите имоти и инвестициите на територията на Република България .',
#   'name': {'local': 'Агенция за недвижими имоти Августа'},
#   'phone': '088 746 4220',
#   'website': 'http://avgustainvest.com/bg/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2e3d46'),
#   'class': 'node',
#   'pos': [42.1567968, 24.7480415],
#   'id': '6017317878',
#   'created': {'version': '1',
#    'timestamp': '2018-10-27T08:39:42Z',
#    'changeset': '63922126',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив', 'housenumber': '21', 'street': 'ул. Ибър'},
#   'building': 'yes',
#   'description': 'Фирмата предлага автобусни екскурзии и почивки, самолетни\nекскурзии и почивки, програми "Златна възраст", круизи, уикенди в страната,\nпешеходни преходи в страната, тиймбилдинг.',
#   'name': {'local': 'ВАНДИ С'},
#   'phone': '032 964 970',
#   'website': 'http://www.wandi-tour.com/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2e3d47'),
#   'class': 'node',
#   'pos': [42.131348, 24.7225173],
#   'id': '6017327052',
#   'created': {'version': '1',
#    'timestamp': '2018-10-27T08:41:38Z',
#    'changeset': '63922170',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив', 'housenumber': '9', 'street': 'ул. София'},
#   'building': 'yes',
#   'description': 'Предлагаме продукти, подобряващи качеството на живот и здравето.',
#   'name': {'local': 'Велмакс Лукс ЕООД'},
#   'phone': '089 420 3224',
#   'website': 'http://welmax.bg/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2e42e9'),
#   'class': 'node',
#   'pos': [42.1270999, 24.787373],
#   'id': '6037456231',
#   'created': {'version': '1',
#    'timestamp': '2018-11-04T19:17:38Z',
#    'changeset': '64175624',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив', 'street': 'ул. Ж.К Тракия 160'},
#   'building': 'yes',
#   'description': 'Основната дейност на фирмата е товаро-разтоварни услуги\nна различни видове машини, фургони, контейнери и други.\nСъщо така извършва и монтаж и демонтаж на метални халета, огради, билбордове.',
#   'name': {'local': 'Автокран Пловдив | АВТОКРАН - 2006 ЕООД'},
#   'phone': '088 822 8926',
#   'website': 'https://2006-crane-rental-agency.business.site/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2e87ce'),
#   'class': 'node',
#   'pos': [42.1661489, 24.7605034],
#   'id': '6082189307',
#   'created': {'version': '1',
#    'timestamp': '2018-11-22T10:15:14Z',
#    'changeset': '64774231',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '180',
#    'street': 'ул. Брезовско Шосе'},
#   'building': 'yes',
#   'description': 'Предмет на дейност на фирмата е внос и търговия на канцеларски материали и ученически пособия от Турция и Дубай.',
#   'name': {'local': 'Канцеларски материали Пловдив | Мавро'},
#   'phone': '089 923 6349',
#   'website': 'http://www.mavro-bg.com/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2ea0b7'),
#   'class': 'node',
#   'pos': [42.156563, 24.7477151],
#   'id': '6109346784',
#   'created': {'version': '1',
#    'timestamp': '2018-12-01T14:06:25Z',
#    'changeset': '65073472',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив', 'housenumber': '25', 'street': 'ул. Ибър'},
#   'building': 'yes',
#   'description': 'Цялостно строителство на сгради и строителни съоражения.',
#   'name': {'local': 'Строителство | Саграда ООД'},
#   'phone': '088 877 5863',
#   'website': 'https://construction-company-9093.business.site/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2f0151'),
#   'class': 'node',
#   'pos': [41.930221, 25.5727119],
#   'id': '6149244239',
#   'created': {'version': '2',
#    'timestamp': '2019-04-13T05:19:15Z',
#    'changeset': '69168538',
#    'uid': '9516754',
#    'user': 'lqlqlqlio'},
#   'address': {'city': 'Хасково',
#    'housenumber': '204',
#    'street': 'ул. България'},
#   'building': 'yes',
#   'description': 'Производител на машини.',
#   'name': {'local': 'ХИДРОПЛАСТФОРМ'},
#   'phone': '038 661 347',
#   'website': 'http://hidroplastform.com/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2f20e5'),
#   'class': 'node',
#   'pos': [42.1311566, 24.9273768],
#   'id': '6184910775',
#   'created': {'version': '1',
#    'timestamp': '2019-01-04T22:08:12Z',
#    'changeset': '66035736',
#    'uid': '6176812'},
#   'address': {'city': 'Садово'},
#   'building': 'yes',
#   'description': 'Фирма Ванко 89 ООД произвежда фъстъчено масло, печени цели фъстъци, с или без сол, печени фъстъци половинки, с или без сол, печени натрошени фъстъци с размери 2-4mm, 2-6mm, 4-6mm, 4-8mm, фъстъчени кремове с вкус на шоколад',
#   'name': {'local': 'ВАНКО - 89'},
#   'phone': '088 782 6396',
#   'website': 'http://www.vanko89.free.bg/index.html'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2f20e6'),
#   'class': 'node',
#   'pos': [41.9343129, 25.5553027],
#   'id': '6184945023',
#   'created': {'version': '1',
#    'timestamp': '2019-01-04T22:17:46Z',
#    'changeset': '66035914',
#    'uid': '6176812'},
#   'address': {'city': 'Хасково',
#    'housenumber': '16',
#    'street': 'ул. Георги Сава Раковски'},
#   'building': 'yes',
#   'description': 'Доставка и монтаж на отоплителни системи на биомаса.\nДоставка и монтаж на слънчеви воднагревателни системи.',
#   'name': {'local': 'Vikom Ltd'},
#   'phone': '038 609 944',
#   'website': 'https://manufacturer-9122.business.site/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2f2e92'),
#   'class': 'node',
#   'pos': [42.1212562, 24.7559987],
#   'id': '6212731747',
#   'created': {'version': '1',
#    'timestamp': '2019-01-16T08:59:36Z',
#    'changeset': '66355797',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '6101',
#    'street': 'ул. Ул.Индустриална'},
#   'building': 'yes',
#   'description': 'Фирма Алутрейдинг ЕООД е от дълго време на пазара и предлага производство и монтаж на перголи, стъклени завеси и парапети. С всеки изминал ден ние се утвръждаваме като предпочитана фирма на пазара. Основно залагаме на качеството на материала.',
#   'name': {'local': 'Парапети Пловдив Алутрейдинг ЕООД'},
#   'phone': '087 614 1232',
#   'website': 'http://alutrading.eu/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2f2e93'),
#   'class': 'node',
#   'pos': [41.9461176, 25.5617143],
#   'id': '6212734918',
#   'created': {'version': '1',
#    'timestamp': '2019-01-16T09:05:49Z',
#    'changeset': '66355931',
#    'uid': '6176812'},
#   'address': {'city': 'Хасково',
#    'housenumber': '45',
#    'street': 'ул. Светлина'},
#   'building': 'yes',
#   'description': 'Голямо разнообразие на кучета. Търговец, на който можете да се доверите.',
#   'name': {'local': 'Внос на кучета | ПУПИ ЕКСПОРТ ИМПОРТ ООД'},
#   'phone': '089 446 7008',
#   'website': 'http://puppy-sale.eu/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2f2eb7'),
#   'class': 'node',
#   'pos': [42.1191871, 24.7864215],
#   'id': '6220630021',
#   'created': {'version': '1',
#    'timestamp': '2019-01-19T09:38:35Z',
#    'changeset': '66448807',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '30',
#    'street': 'ул. Недялка Шилева'},
#   'building': 'yes',
#   'description': 'Производител на разнообразни пластмасови изделия в неограничено количество от всички видове пластмаса. Разполага с високо технологични, интелигентни, немски и италиянски шприц машини с капацитет от 100 до 900 тона.',
#   'name': {'local': 'Армитех'},
#   'phone': '032 680 027',
#   'website': 'http://armitechplast.com/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2f2eb8'),
#   'class': 'node',
#   'pos': [42.1608946, 24.7692498],
#   'id': '6220655650',
#   'created': {'version': '1',
#    'timestamp': '2019-01-19T09:46:25Z',
#    'changeset': '66448925',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '6',
#    'street': 'ул. Рогошко Шосе'},
#   'building': 'yes',
#   'description': 'Актуал Индъстрис ООД е търговска компания предлагаща на българския пазар индустриални лепила на Henkel за различните промишлени отрасли: полиграфия, преработка на хартия, етикетиране, ламиниране на гъвкави опаковки, мебелна индустрия, обувна индустрия.',
#   'name': {'local': 'Actual Industries'},
#   'phone': '032 906 000',
#   'website': 'http://www.actual-industries.com/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2f32af'),
#   'class': 'node',
#   'pos': [42.1521263, 24.7575431],
#   'id': '6230571051',
#   'created': {'version': '1',
#    'timestamp': '2019-01-23T16:47:59Z',
#    'changeset': '66575637',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '188',
#    'street': 'ул. 6-Ти Септември'},
#   'building': 'yes',
#   'description': 'Счетоводни услуги, Финансови услуги, Данъчни услуги, Услуги свързани с персонала - заплати и осигуровки, консултантски услуги, правни услуги.',
#   'name': {'local': 'Ютилита ЕООД'},
#   'phone': '088 797 6749',
#   'website': 'http://www.yutilita.com/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2f3977'),
#   'class': 'node',
#   'pos': [42.1381029, 24.7436859],
#   'id': '6248811569',
#   'created': {'version': '1',
#    'timestamp': '2019-01-31T08:20:19Z',
#    'changeset': '66793937',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив'},
#   'building': 'yes',
#   'description': 'Фитотерапия; Хомеопатия; Литотерапия; Апитерапия; Аюрведа; Ароматерапия; Бахови есенции и др. ',
#   'name': {'local': 'ХОЛИСТИЧЕН ЦЕНТЪР ТРАНСМЕД ООД'},
#   'phone': '088 752 4826',
#   'website': 'http://transmedbg.com/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2f3a06'),
#   'class': 'node',
#   'pos': [42.1521985, 24.7493673],
#   'id': '6255663522',
#   'created': {'version': '2',
#    'timestamp': '2020-05-13T12:41:26Z',
#    'changeset': '85145823',
#    'uid': '7753461'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '28',
#    'street': 'ул. 4-Ти Януари'},
#   'building': 'yes',
#   'description': 'Индивидуални оферти за почивки и хотелски резервации в България и чужбина, Ученически екскурзии и лагери в България и чужбина, Тиймбилдинги, Конгресни и фирмени мероприятия, Екзотични дестинации и круизи, Самолетни билети, Медицински и туристически',
#   'phone': '032 262 264',
#   'website': 'http://www.evrotoptour.com/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2f5adb'),
#   'class': 'node',
#   'pos': [42.1521969, 24.7496656],
#   'id': '6291616546',
#   'created': {'version': '2',
#    'timestamp': '2020-05-13T12:41:26Z',
#    'changeset': '85145823',
#    'uid': '7753461'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '28',
#    'street': 'ул. 4-Ти Януари'},
#   'building': 'yes',
#   'description': 'Фирма Магистрой Експрес извършва качествени ремонти на покриви вече 28 години.',
#   'name': {'local': 'Магистрой Експрес'},
#   'phone': '089 946 5219',
#   'website': 'https://magistroi-plovdiv.business.site/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f2fd764'),
#   'class': 'node',
#   'pos': [42.1192603, 24.7840722],
#   'id': '6472091897',
#   'created': {'version': '1',
#    'timestamp': '2019-05-14T08:43:37Z',
#    'changeset': '70222927',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '10',
#    'street': 'ул. Инж. Асен Йорданов'},
#   'building': 'yes',
#   'description': 'ЕТ Радина е основана през 1991 година. Нейното развитие се опира на дългогодишния опит в областта на приложната механика на доц. д-р инж. Марин Памукчиев, преподавател в Русенския Университет, а по-късно и в Технически Университет София - филиал Пловдив. ',
#   'name': {'local': 'Radina-M'},
#   'phone': '088 760 3983',
#   'website': 'http://www.radina-m.com/bg/'},
#  {'_id': ObjectId('5f2d4c5bf80d478f6f300fab'),
#   'class': 'node',
#   'pos': [42.1378714, 24.7512852],
#   'id': '6542337138',
#   'created': {'version': '2',
#    'timestamp': '2019-06-16T22:49:12Z',
#    'changeset': '71311538',
#    'uid': '9451067',
#    'user': 'b-jazz-bot'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '5',
#    'postcode': 4000,
#    'street': 'ул. Костаки Пеев'},
#   'healthcare': {'healthcare': 'psychotherapist',
#    'speciality': 'psychotherapist'},
#   'name': {'local': 'Консултативен център "Светът е шарен"'},
#   'website': 'https://www.psihologdobreva.com/'},
#  {'_id': ObjectId('5f2d4c5cf80d478f6f30ad95'),
#   'class': 'node',
#   'pos': [42.1612307, 24.7678859],
#   'id': '6645564564',
#   'created': {'version': '1',
#    'timestamp': '2019-07-25T04:46:36Z',
#    'changeset': '72626124',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '3',
#    'street': 'ул. Рогошко Шосе'},
#   'description': 'Проектиране и производство на нестандартно оборудване, машини и съоръжения.\n    Проектиране и производство на метални конструкции и изделия от метал - метална дограма, парапети, огради, стълби, метални съдове, метални шкафове, гардероби и други.',
#   'man_made': 'works',
#   'name': {'local': 'БИМЕКС ИНЖЕНЕРИНГ'},
#   'phone': '032 696 688',
#   'website': 'http://www.bimex-ing.com/'},
#  {'_id': ObjectId('5f2d4c5cf80d478f6f30d9a9'),
#   'class': 'node',
#   'pos': [42.1393095, 24.7503613],
#   'id': '6734809350',
#   'created': {'version': '2',
#    'timestamp': '2020-05-20T11:09:51Z',
#    'changeset': '85495054',
#    'uid': '3199858'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '7',
#    'street': 'ул. Цанко Дюстабанов'},
#   'description': 'Д-р Вълчева /Деляна Вълчева/. Дейност: Психолог,Психотерапевт, Доктор по невропсихология с дългогодишен опит - психотерапия, индивидуално и семейно консултиране, психологически изследвания, диагностика и др.',
#   'healthcare': 'psychotherapist',
#   'name': {'local': 'Психотерапевтичен кабинет | Д-р Вълчева'},
#   'phone': '089 933 2037',
#   'website': 'https://phsihoterapevtichen-kabinet.business.site/'},
#  {'_id': ObjectId('5f2d4c5cf80d478f6f30d9aa'),
#   'class': 'node',
#   'pos': [42.0121988, 25.0055002],
#   'id': '6734843452',
#   'created': {'version': '2',
#    'timestamp': '2020-05-20T11:53:53Z',
#    'changeset': '85498101',
#    'uid': '3199858'},
#   'address': {'city': 'Златовръх', 'housenumber': '9', 'street': 'ул. Речна'},
#   'craft': 'winery',
#   'description': 'Винарска изба Ничев е създадена през 2014 година и е разположена в сърцето на маврудовия регион - с. Златовръх на 10 км от Асеновград.',
#   'name': {'local': 'Винарска Изба Ничев'},
#   'phone': '089 345 9796',
#   'website': 'https://vinarna-nitchev.business.site/'},
#  {'_id': ObjectId('5f2d4c5cf80d478f6f310467'),
#   'class': 'node',
#   'pos': [42.0987819, 25.2406612],
#   'id': '6790484848',
#   'created': {'version': '3',
#    'timestamp': '2020-05-20T11:53:53Z',
#    'changeset': '85498101',
#    'uid': '3199858'},
#   'address': {'city': 'Първомай',
#    'housenumber': '68',
#    'street': 'ул. Стефан Стамболов'},
#   'description': 'Производство на едрогабаритен пластмасов амбалаж, тръби, бидони и стоки за бита от полипропилен и полиетилен.',
#   'man_made': 'works',
#   'name': {'local': 'ХИМПЛАСТ'},
#   'phone': '0888 808260',
#   'website': 'https://himplast.business.site/'},
#  {'_id': ObjectId('5f2d4c5cf80d478f6f3117a2'),
#   'class': 'node',
#   'pos': [42.1513206, 24.7444413],
#   'id': '6825435243',
#   'created': {'version': '1',
#    'timestamp': '2019-09-26T10:28:43Z',
#    'changeset': '74950487',
#    'uid': '3423733',
#    'user': 'A_Ku'},
#   'historic': 'monument',
#   'name': {'English': 'Monument of Unification',
#    'local': 'Паметник на Съединението'},
#   'start_date': '1985',
#   'website': 'http://www.visitplovdiv.com/en/node/643'},
#  {'_id': ObjectId('5f2d4c5cf80d478f6f3123fc'),
#   'class': 'node',
#   'pos': [42.1663709, 24.7605097],
#   'id': '6970754910',
#   'created': {'version': '1',
#    'timestamp': '2019-11-13T06:29:19Z',
#    'changeset': '76993120',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '180',
#    'street': 'ул. Брезовско Шосе'},
#   'description': 'Създадена през 1990 година, Марвас - 90 е специализирана в производството на яйца и птици (стокови носачки). ',
#   'man_made': 'works',
#   'name': {'local': 'СД Марвас-90'},
#   'phone': '088 610 0771',
#   'website': 'https://marvas-90.com/'},
#  {'_id': ObjectId('5f2d4c5cf80d478f6f312b1b'),
#   'class': 'node',
#   'pos': [42.2649399, 24.7223359],
#   'id': '7025871757',
#   'created': {'version': '1',
#    'timestamp': '2019-12-02T11:50:20Z',
#    'changeset': '77817780',
#    'uid': '6176812'},
#   'address': {'city': 'Граф Игнатиево',
#    'housenumber': '3',
#    'street': 'ул. Явор'},
#   'man_made': 'works',
#   'name': {'local': 'АГБ-2004 ЕООД'},
#   'phone': '087 868 2889',
#   'website': 'http://geo.bg/banev/'},
#  {'_id': ObjectId('5f2d4c5cf80d478f6f3130ac'),
#   'class': 'node',
#   'pos': [42.0584429, 25.2629321],
#   'id': '7071905376',
#   'created': {'version': '7',
#    'timestamp': '2020-01-25T12:22:42Z',
#    'changeset': '80069759',
#    'uid': '10520536',
#    'user': 'Stalewhr'},
#   'description': 'Паметник',
#   'historic': 'memorial',
#   'name': {'local': 'Паметна плоча на загиналите през Втората световна война жители на селото'},
#   'website': 'https://bg.wikipedia.org/wiki/%D0%91%D1%8F%D0%BB%D0%B0_%D1%80%D0%B5%D0%BA%D0%B0_(%D0%BE%D0%B1%D0%BB%D0%B0%D1%81%D1%82_%D0%9F%D0%BB%D0%BE%D0%B2%D0%B4%D0%B8%D0%B2)#/media/%D0%A4%D0%B0%D0%B9%D0%BB:Byala_reka,_Plovdiv_Province_-_war_memorial.jpg'},
#  {'_id': ObjectId('5f2d4c5cf80d478f6f31500b'),
#   'class': 'node',
#   'pos': [42.1669857, 24.8112941],
#   'id': '7241873742',
#   'created': {'version': '1',
#    'timestamp': '2020-02-25T08:56:18Z',
#    'changeset': '81444947',
#    'uid': '6176812'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '5',
#    'street': 'ул. Рогошко Шосе'},
#   'description': '“Михайлов Комерс” ЕООД е създадена през 2002 година в гр. Пловдив, с предмет на дейност, пласмент на хартии и картони и тяхната преработка.',
#   'man_made': 'works',
#   'name': {'local': 'МИХАЙЛОВ КОМЕРС ЕООД'},
#   'phone': '032 950 759',
#   'website': 'http://mihajlovcommerceltd.com/bg/index.php'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f31def1'),
#   'class': 'way',
#   'node_refs': ['829171854',
#    '3932107985',
#    '3161747790',
#    '3161747793',
#    '1090731143',
#    '3161747796',
#    '3161747797',
#    '3161747795',
#    '1090731215',
#    '1090731196',
#    '3932107984',
#    '829171811',
#    '829171834',
#    '3932107981',
#    '1090731022',
#    '3932107973',
#    '3161747788',
#    '1090731097',
#    '3161747786',
#    '3161747785',
#    '3932107972',
#    '3161747787',
#    '1090731245',
#    '1090730956',
#    '3161747789',
#    '829171832',
#    '829171854'],
#   'id': '69117838',
#   'created': {'version': '9',
#    'timestamp': '2016-10-25T17:13:33Z',
#    'changeset': '43166186',
#    'uid': '4001517',
#    'user': 'AAT_BG'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '10',
#    'postcode': 4017,
#    'street': 'бул. Източен'},
#   'leisure': 'stadium',
#   'name': {'local': 'Стадион "Христо Ботев"',
#    'English': 'Hristo Botev Stadium'},
#   'sport': 'soccer',
#   'website': 'https://botevplovdiv.bg',
#   'wikidata': 'Q849662'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f31e1a4'),
#   'class': 'way',
#   'node_refs': ['1026796827',
#    '1026796967',
#    '1026797501',
#    '1026796921',
#    '1026796827'],
#   'id': '88389248',
#   'created': {'version': '2',
#    'timestamp': '2019-07-07T13:45:10Z',
#    'changeset': '71982777',
#    'uid': '237594',
#    'user': 'ivanatora'},
#   'leisure': 'pitch',
#   'sport': 'soccer',
#   'website': 'http://www.arena-veld.com/'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f3210da'),
#   'class': 'way',
#   'node_refs': ['1619368909',
#    '1619368877',
#    '2156667761',
#    '1619368809',
#    '1619368815',
#    '1619368823',
#    '1619368842',
#    '1619368863',
#    '1619368849',
#    '1619368872',
#    '1619368895',
#    '1619368909'],
#   'id': '148878993',
#   'created': {'version': '5',
#    'timestamp': '2017-04-30T11:31:00Z',
#    'changeset': '48279418',
#    'uid': '27264',
#    'user': 'Squiffy'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '76',
#    'postcode': 4000,
#    'street': 'ул. Филип Македонски'},
#   'building': {'type': 'warehouse', 'levels': '1'},
#   'name': {'local': 'Статекс ООД -склад прежди'},
#   'name_1': 'Statex LTD',
# ...
#   'name': {'local': 'Air Belozem'},
#   'surface': 'grass',
#   'website': 'http://air.belozem.com/index.php'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f3329fb'),
#   'class': 'way',
#   'node_refs': ['5365643960',
#    '5365643973',
#    '5365643964',
#    '5365643965',
#    '5365643966',
#    '5365643967',
#    '5365643961',
#    '5365643968',
#    '5365643962',
#    '5365643969',
#    '5365643970',
#    '5365643971',
#    '5365643972',
#    '5365643963',
#    '5365643974',
#    '5365643975',
#    '5365643976',
#    '5365643977',
#    '5365643978',
#    '5365643979',
#    '5365643980',
#    '5365643981',
#    '5365643960'],
#   'id': '556227410',
#   'created': {'version': '1',
#    'timestamp': '2018-01-27T10:18:23Z',
#    'changeset': '55799177',
#    'uid': '5430315',
#    'user': 'skyzebra'},
#   'address': {'city': 'Plovdiv', 'postcode': 4000},
#   'building': 'yes',
#   'name': {'local': 'Roman Amphitheatre'},
#   'phone': '+359 88 867 9079',
#   'website': 'https://antichen-stadion-plovdiv.bg/'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f332a06'),
#   'class': 'way',
#   'node_refs': ['5389314474',
#    '5389314475',
#    '5389314476',
#    '5389314477',
#    '5389314478',
#    '5389314479',
#    '5389314474'],
#   'id': '558735341',
#   'created': {'version': '2',
#    'timestamp': '2018-02-05T09:14:13Z',
#    'changeset': '56078976',
#    'uid': '1886651',
#    'user': 'Fillipoff'},
#   'landuse': 'commercial',
#   'name': {'local': 'Triumf'},
#   'website': 'https://www.triumf.bg',
#   'wheelchair': 'yes'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f334884'),
#   'class': 'way',
#   'node_refs': ['6087046083',
#    '6087046084',
#    '6087047185',
#    '6087047186',
#    '6087047187',
#    '6087047188',
#    '6087047189',
#    '6087047190',
#    '6087047191',
#    '6087047192',
#    '6087046083'],
#   'id': '648343357',
#   'created': {'version': '2',
#    'timestamp': '2019-03-23T23:11:53Z',
#    'changeset': '68457555',
#    'uid': '9451067',
#    'user': 'b-jazz-bot'},
#   'address': {'city': 'Пловдив', 'housenumber': '2', 'street': 'ул. Правда'},
#   'building': 'commercial',
#   'name': {'local': 'Олимекс ЕООД', 'English': 'Olimex LTD'},
#   'phone': '+359 32 626 259',
#   'website': 'https://www.olimex.com/'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f337b1d'),
#   'class': 'way',
#   'node_refs': ['6875326524', '6875326525', '6875326526', '6875326524'],
#   'id': '734160285',
#   'created': {'version': '1',
#    'timestamp': '2019-10-13T13:33:56Z',
#    'changeset': '75624148',
#    'uid': '9516754',
#    'user': 'lqlqlqlio'},
#   'building': 'yes',
#   'club': 'sport',
#   'name': {'local': 'Стрелбищен комплекс "Диана"'},
#   'operator': '„Геодар“ ЕООД',
#   'sport': 'shooting',
#   'website': 'http://www.geodar.org/'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f337cc6'),
#   'class': 'way',
#   'node_refs': ['7006584674',
#    '7006584675',
#    '7006584676',
#    '7006584677',
#    '7006584678',
#    '7006584674'],
#   'id': '749248098',
#   'created': {'version': '1',
#    'timestamp': '2019-11-24T18:27:01Z',
#    'changeset': '77489489',
#    'uid': '9516754',
#    'user': 'lqlqlqlio'},
#   'leisure': 'resort',
#   'name': {'local': 'вилно селище "Сабазий"'},
#   'resort': 'guest_house',
#   'website': 'https://www.sabazius.eu'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f3389f6'),
#   'class': 'way',
#   'node_refs': ['7660400964',
#    '7660400965',
#    '7660400966',
#    '7660400967',
#    '7660400964'],
#   'id': '820380758',
#   'created': {'version': '1',
#    'timestamp': '2020-06-28T09:43:37Z',
#    'changeset': '87245203',
#    'uid': '9516754',
#    'user': 'lqlqlqlio'},
#   'building': 'industrial',
#   'name': {'local': 'Монолит АД Бетонов център'},
#   'website': 'http://www.monolitbg.com'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f338b33'),
#   'class': 'relation',
#   'member_refs': ['798414560',
#    '798414563',
#    '3070643',
#    '2275549',
#    '1981022',
#    '1981030',
#    '912994',
#    '1570144',
#    '192031',
#    '3084125',
#    '9933591',
#    '8541760'],
#   'id': '1175728',
#   'created': {'version': '119',
#    'timestamp': '2020-04-30T15:16:22Z',
#    'changeset': '84422296',
#    'uid': '8396056',
#    'user': 'TWMICHAL'},
#   'description': 'Cork (IE) - Dublin (IE) - Liverpool (GB) - Hull (GB) - Rotterdam (NL) - Nijmegen (NL) - Worms (DE) - Donau (AT) - Bratislava (SK) - Iwonicz-Zdrój (PL) - Border UA/PL',
#   'distance': '4390',
#   'name': {'local': 'European long distance path E8',
#    'English': 'European long distance path E8'},
#   'network': 'iwn',
#   'operator': {'operator': 'European Ramblers Association',
#    'bg': 'Български туристически съюз',
#    'de': 'Deutscher Wanderverband',
#    'ie': 'Mountaineering Council of Ireland',
#    'nl': 'Stichting Wandelplatform',
#    'pl': 'Polskie Towarzystwo Turystyczno-Krajoznawcze',
#    'sk': 'Klub slovenských turistov'},
#   'osmc': {'symbol': 'blue:blue::E8:yellow'},
#   'ref': 'E8',
#   'route': 'hiking',
#   'type': 'route',
#   'website': 'http://www.era-ewv-ferp.com/index.php?topmenu_id=29&id=29&page_id=112&module=text',
#   'wikidata': 'Q1377713'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f338be6'),
#   'class': 'relation',
#   'member_refs': ['144139122',
#    '144139132',
#    '395085608',
#    '281091448',
#    '395085604',
#    '423308948',
#    '395084850',
#    '395084849',
#    '146222151',
#    '146222189',
#    '144139140',
#    '144139173'],
#   'id': '1952398',
#   'created': {'version': '10',
#    'timestamp': '2018-12-03T19:40:58Z',
#    'changeset': '65137205',
#    'uid': '177389',
#    'user': 'Garmin-User'},
#   'admin_level': '7',
#   'boundary': 'administrative',
#   'name': {'local': 'Ардино', 'English': 'Ardino'},
#   'type': 'boundary',
#   'website': 'http://www.ardino.bg'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f338bfa'),
#   'class': 'relation',
#   'member_refs': ['146222118',
#    '146222186',
#    '146222188',
#    '146222173',
#    '146222160',
#    '146222179',
#    '146222178',
#    '256956419',
#    '796427938',
#    '803382553',
#    '796427936',
#    '796428292',
#    '796423214',
#    '796421698',
#    '796421699'],
#   'id': '1974021',
#   'created': {'version': '17',
#    'timestamp': '2020-05-13T14:32:08Z',
#    'changeset': '85150931',
#    'uid': '150201',
#    'user': 'plamen'},
#   'admin_level': '7',
#   'boundary': 'administrative',
#   'name': {'local': 'Смолян', 'English': 'Smolian'},
#   'type': 'boundary',
#   'website': 'http://www.smolyan.bg'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f338c53'),
#   'class': 'relation',
#   'member_refs': ['16239',
#    '52411',
#    '186382',
#    '214885',
#    '307787',
#    '51684',
#    '50046',
#    '79510',
#    '54224',
#    '2202162',
#    '51477',
#    '192307',
#    '62273',
#    '365331',
#    '72594',
#    '72596',
#    '2171347',
#    '365307',
#    '47796',
#    '21335',
#    '49715',
#    '295480',
#    '1311341',
#    '218657',
#    '14296',
#    '52822',
#    '90689'],
#   'id': '2668952',
#   'created': {'version': '124',
#    'timestamp': '2020-07-01T04:33:56Z',
#    'changeset': '87374935',
#    'uid': '682928'},
#   'alt_name': {'vi': 'Liên hiệp châu Âu'},
#   'fixme': {'fixme': 'fixme:pl',
#    'en': '<<The "name" tag should contain the name in one of the official languages (Polish) or should be removed.>> --fixme:pl && Google Translate',
#    'pl': 'Znacznik „name” powinien zawierać nazwę w jednym z oficjalnych języków (polskim) lub powinien zostać usunięty.'},
#   'name': {'local': 'European Union', 'English': 'European Union'},
#   'note': {'en': 'This is not a boundary relation. The boundary of the EU is the sum of external boudnaries of its member states. Mapping it separately is unnecessary',
#    'pl': 'To nie jest relacja granic państwowych. Granica UE jest sumą granic wszystkich państw członkowskich, nie ma potrzeby nanosić jej na mapę osobno.'},
#   'population': '503679730',
#   'short_name': {'be': 'ЕС',
#    'bg': 'ЕС',
#    'cs': 'EU',
#    'da': 'EU',
#    'de': 'EU',
#    'el': 'ΕΕ',
#    'en': 'EU',
#    'eo': 'EU',
#    'es': 'UE',
#    'et': 'EL',
#    'fi': 'EU',
#    'fr': 'UE',
#    'ga': 'AE',
#    'hr': 'EU',
#    'hu': 'EU',
#    'it': 'UE',
#    'lt': 'ES',
#    'lv': 'ES',
#    'mi': 'KŪ',
#    'mt': 'UE',
#    'nl': 'EU',
#    'pl': 'UE',
#    'pt': 'UE',
#    'ro': 'UE',
#    'ru': 'ЕС',
#    'sk': 'EÚ',
#    'sl': 'EU',
#    'sv': 'EU',
#    'tr': 'AB'},
#   'type': 'treaty',
#   'website': 'https://europa.eu',
#   'wikidata': 'Q458'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f338d79'),
#   'class': 'relation',
#   'member_refs': ['453541755', '496284885'],
#   'id': '7285989',
#   'created': {'version': '1',
#    'timestamp': '2017-05-27T10:32:56Z',
#    'changeset': '49021393',
#    'uid': '27264',
#    'user': 'Squiffy'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '59',
#    'postcode': 4004,
#    'street': 'ул. Димитър Талев'},
#   'building': {'type': 'kindergarten', 'levels': '2'},
#   'name': {'local': 'ЦДГ Вяра'},
#   'phone': '+359 32 692 737',
#   'type': 'multipolygon',
#   'website': 'http://www.dg-vyara.com/',
#   'wheelchair': 'yes'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f338d8e'),
#   'class': 'relation',
#   'member_refs': ['496622502'],
#   'id': '7292003',
#   'created': {'version': '5',
#    'timestamp': '2020-04-12T17:59:59Z',
#    'changeset': '83435186',
#    'uid': '4262072',
#    'user': 'IDKS'},
#   'address': {'city': 'Пловдив',
#    'housenumber': '1',
#    'postcode': 4000,
#    'street': 'ул. Перущица'},
#   'building': 'hospital',
#   'layer': '1',
#   'name': {'local': 'УМБАЛ ПЪЛМЕД ООД',
#    'English': 'University Hospital "Pulmed"'},
#   'phone': '+35932607300',
#   'type': 'multipolygon',
#   'website': 'https://www.hospitalpulmed.bg/'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f338d8f'),
#   'class': 'relation',
#   'member_refs': ['496622554', '193586012'],
#   'id': '7292004',
#   'created': {'version': '5',
#    'timestamp': '2020-04-12T17:59:59Z',
#    'changeset': '83435186',
#    'uid': '4262072',
#    'user': 'IDKS'},
#   'building': {'type': 'hospital', 'levels': '12'},
#   'emergency': 'ambulance_station',
#   'name': {'local': 'УМБАЛ Свети Георги',
#    'English': 'University Hospital "St George"'},
#   'phone': '+35932602211',
#   'type': 'multipolygon',
#   'website': 'http://www.unihosp.com'},
#  {'_id': ObjectId('5f2d4c5df80d478f6f338e30'),
#   'class': 'relation',
#   'member_refs': ['303150211',
#    '303150206',
#    '303150217',
#    '303150207',
#    '303150205',
#    '303150214',
#    '303150208',
#    '303150216',
#    '303150213',
#    '303150210',
#    '303150215',
#    '303150209',
#    '303150212',
#    '119205369',
#    '303150218',
#    '617796739',
#    '175938584',
#    '51040942',
#    '51040942',
#    '175938579',
#    '175938582',
#    '617796746',
#    '175938572',
#    '175938573',
#    '782439050',
#    '617796749',
#    '439704718',
#    '617796750',
#    '782439051',
#    '348940619',
#    '348940617',
#    '348934989',
#    '348933035',
#    '617796762',
#    '467379637',
#    '467379637',
#    '175938586',
#    '175938586',
#    '617845559',
#    '55333499',
#    '41241708',
#    '164918541',
#    '30100633',
#    '168348018',
#    '481511270',
#    '30100635',
#    '719483050',
#    '719482076',
#    '719482077',
#    '157155915',
#    '157155922',
#    '719428788',
#    '719411123',
#    '719411127',
#    '719411128',
#    '619933430',
#    '619940879',
#    '619940880',
#    '619940882',
#    '619940881',
#    '619940883',
#    '338171744',
#    '338171745',
#    '157152587',
#    '619940886',
#    '305534520',
#    '305534523',
#    '619940888',
#    '619944439',
#    '606838432',
#    '606838442',
#    '157123611',
#    '619944441',
#    '606838428',
#    '696121126',
#    '606838446',
#    '498869968',
#    '606838449',
#    '696121125',
#    '41418511',
#    '231383528',
#    '608730336',
#    '606838325',
#    '608730335',
#    '157108662',
#    '619945791',
#    '41902982',
#    '41902978',
#    '41902981',
#    '41902972',
#    '41902977',
#    '41902975',
#    '610475896',
#    '307456753',
#    '497593849',
#    '619945792',
#    '722013156',
#    '497593845',
#    '606159318',
#    '606159317',
#    '722013158',
#    '616134366',
#    '607938425',
#    '607938428',
#    '616134374',
#    '616134376',
#    '607938423',
#    '616134378',
#    '607938422',
#    '616134381',
#    '41907708',
#    '41944430',
#    '607938437',
#    '607938438',
#    '607938420',
#    '607938439',
#    '606159308',
#    '606159309',
#    '41907697',
#    '41907694',
#    '610444452',
#    '610444453',
#    '610444444',
#    '41907690',
#    '305546086',
#    '610444441',
#    '305546088',
#    '305546085',
#    '610444440',
#    '610444439',
#    '610444437',
#    '305546087',
#    '608093665',
#    '608093662',
#    '164916547',
#    '157053472',
#    '307457949',
#    '307457947',
#    '782439057',
#    '782439056',
#    '608093658',
#    '608093655',
#    '606090667',
#    '606090668',
#    '608093652',
#    '606090666',
#    '606090665',
#    '608093645',
#    '608093649',
#    '608093647',
#    '608093650',
#    '608093643',
#    '606090664',
#    '606090662',
#    '608093641',
#    '606090680',
#    '606090681',
#    '608683341',
#    '608683336',
#    '608683330',
#    '794284794',
#    '794284793',
#    '631377351',
#    '631377350',
#    '619948114',
#    '631377347',
#    '631377352',
#    '631377353',
#    '608683306',
#    '617434546',
#    '720008236',
#    '611605002',
#    '503451228',
#    '503451227',
#    '503451226',
#    '503451225',
#    '503451224',
#    '368808314',
#    '503451223',
#    '503451221',
#    '503451229',
#    '368808311',
#    '368520326',
#    '620020075',
#    '368808310',
#    '720021485',
#    '720021486',
#    '720021487',
#    '720021488',
#    '368520335',
#    '368808315',
#    '368808319',
#    '503856890',
#    '503856891',
#    '305549873',
#    '368520328',
#    '103450310',
#    '503856886',
#    '157057293',
#    '157057277',
#    '368808316',
#    '593489426',
#    '620020080',
#    '237904453',
#    '620020082',
#    '237904466',
#    '620020086',
#    '513396018',
#    '513396018',
#    '284774376',
#    '176992328',
#    '368808320',
#    '383481080',
#    '157057251',
#    '305549874',
#    '305549872',
#    '157057284',
#    '237904460',
#    '616334424',
#    '157057335',
#    '620020087',
#    '157060999',
#    '157061004',
#    '157061006',
#    '258894581',
#    '157086454',
#    '301327782',
#    '157062295',
#    '179653760',
#    '179655797',
#    '258893107',
#    '179655743',
#    '179655794',
#    '164769111',
#    '263067216',
#    '723235679',
#    '620031912',
#    '246429941',
#    '782439059',
#    '157091507',
#    '225091431',
#    '157091505',
#    '157091505',
#    '157091445',
#    '127429637',
#    '157091438',
#    '127429633',
#    '127429638',
#    '127429635',
#    '157091432',
#    '624243993',
#    '157091392',
#    '185070287',
#    '620050699',
#    '620050698',
#    '620051731',
#    '620051733',
#    '620055796',
#    '331961609',
#    '287055218',
#    '354224950',
#    '354224950',
#    '782439061',
#    '287055215',
#    '782439062',
#    '782439063',
#    '785846996',
#    '103018515',
#    '810205811',
#    '620055800',
#    '103018450',
#    '620055801',
#    '620055803',
#    '279368645',
#    '620060943',
#    '279368613',
#    '782439065',
#    '279368610',
#    '338094263',
#    '279368633',
#    '620060952',
#    '782439068',
#    '279368647',
#    '587419983',
#    '587419986',
#    '620060960',
#    '810197313',
#    '279368621',
#    '782439070',
#    '279368599',
#    '782439072',
#    '103764500',
#    '329722724',
#    '782439073',
#    '424592121',
#    '494901900',
#    '494901899',
#    '103764479',
#    '620060970',
#    '494901825',
#    '494901823',
#    '103764433',
#    '494901754',
#    '620060981',
#    '620060983',
#    '782439074',
#    '494901729',
#    '620063023',
#    '620063025',
#    '103764461',
#    '620063027',
#    '397463904',
#    '397463885',
#    '620063028',
#    '397463871',
#    '397463892',
#    '397463893',
#    '620064756',
#    '620064757',
#    '620064758',
#    '620064759',
#    '494981124',
#    '494981103',
#    '494981102',
#    '620064760',
#    '719439565',
#    '397505063',
#    '129127285',
#    '620064762',
#    '657964173',
#    '657964174',
#    '397480246',
#    '657964175',
#    '714111811',
#    '714111810',
#    '656323097',
#    '656323098',
#    '657964178',
#    '657964180',
#    '656279914',
#    '656279910',
#    '485169601',
#    '657964181',
#    '703994399',
#    '656279894',
#    '656279888',
#    '657964183',
#    '656266146',
#    '657964185',
#    '656334536',
#    '657964187',
#    '30471205',
#    '30471214',
#    '683261385',
#    '30471212',
#    '30471211',
#    '30471210',
#    '457825586',
#    '30471207'],
#   'id': '8541760',
#   'created': {'version': '41',
#    'timestamp': '2020-05-31T11:23:15Z',
#    'changeset': '86005747',
#    'uid': '1454334'},
#   'name': {'local': 'European long distance path E8 - part Bulgaria'},
#   'network': 'iwn',
#   'operator': 'European Ramblers Association',
#   'osmc': {'symbol': 'blue:blue:blue:E8:yellow'},
#   'ref': 'E8',
#   'route': 'hiking',
#   'type': 'route',
#   'website': 'http://www.era-ewv-ferp.com/index.php?topmenu_id=29&id=29&page_id=112&module=text',
#   'wikidata': 'Q1377713'}]

# %%
## Improvement 4.1
sbg.count_documents({"place": {"$exists": True}, "is_in":{"$exists": False}})
# Out:
# 318

# %%
dict(sbg.find_one({"address": {"$exists": True}, "place": {"$exists": False}, "address.street": {"$exists": False}}))
# Out:
# {'_id': ObjectId('5f2d4c56f80d478f6f22da25'),
#  'class': 'node',
#  'pos': [41.932002, 25.5591893],
#  'id': '1197123593',
#  'created': {'version': '4',
#   'timestamp': '2019-11-27T20:47:11Z',
#   'changeset': '77652773',
#   'uid': '9202927',
#   'user': 'Araucaria_araucana'},
#  'address': {'housenumber': '7-А'}}

# %%
## Improvement 4.2
node_id = dict(sbg.find_one({
                        "address": {"$exists": True}, 
                        "place": {"$exists": False}, 
                        "address.street": {"$exists": False}}))["id"]
list(sbg.find({
                    "class": "way",
                    "node_refs": {
                        "$elemMatch": {
                            "$eq": node_id
                        }}}))
# Out:
# [{'_id': ObjectId('5f2d4c5df80d478f6f31f364'),
#   'class': 'way',
#   'node_refs': ['1197126729',
#    '1197123193',
#    '2463960328',
#    '1197126242',
#    '1197125395',
#    '1197126836',
#    '1197122184',
#    '2463960335',
#    '1197123477',
#    '1197128935',
#    '1197125276',
#    '1197126667',
#    '2463960327',
#    '1197128980',
#    '1197127481',
#    '1197129227',
#    '1197123530',
#    '1197127047',
#    '1197128582',
#    '1197125495',
#    '1197127541',
#    '1197123593',
#    '1197123148',
#    '1197129407',
#    '1197126729'],
#   'id': '103690885',
#   'created': {'version': '4',
#    'timestamp': '2019-12-13T15:32:05Z',
#    'changeset': '78381805',
#    'uid': '9516754',
#    'user': 'lqlqlqlio'},
#   'address': {'city': 'Хасково',
#    'housenumber': '7',
#    'postcode': 6300,
#    'street': 'ул. Сан Стефано'},
#   'building': {'type': 'apartments', 'levels': '4'},
#   'old_name': 'Мебелен магазин'}]
